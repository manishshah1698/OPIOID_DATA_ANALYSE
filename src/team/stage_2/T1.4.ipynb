# %% [markdown]
# ## Project Stage - II (Data Modeling)

# %% [markdown]
# ## Goals
#
# The goal of Stage II is to develop the data for modeling and comparative analysis. Here you will be graphically comparing how different states are doing with respect to opioid mortality rate. And you will be also analysing county based information for different states in the US.

# %% [markdown]
# Dataset:
#
# We are going to use historical dataset here for opioid related mortality from 1999 -2019 for different causes of death. Extracted from:
# - https://wonder.cdc.gov/wonder/help/ucd.html#Drug/Alcohol%20Induced%20Causes
# - File: `./data/1999-2020_Drug_Overdose_By_Category.csv`

# %% [markdown]
# ### Tasks:
#
# #### Task 1: (100 pts)
# - Team: (40)
#     - **T1.1** Import the historical data from: `./data/1999-2020_Drug_Overdose_By_Category.xls` (10 pts)
#         - Identify peaks in US Opioid Mortality
#             - Normalize the mortality by population
#             - Calculate mean for states and then mean for US per year
#             - Plot a line graph
#                 - https://plotly.com/python/line-charts/
#         - Discuss why there was a peak
#     - **T1.2** Identify trends in states (10 pts)
#          - Identify top 5 states which are increasing in their opioid numbers
#          - Identify top 5 states which are reducing their opioid numbers
#
#     - **T1.3** Plot a graph of the aforementioned states (T1.2) in a line graph (10 pts)
#          - Two graphs with 5 lines each representing the states.
#
#     - **T1.4** Plot a scatter plot graph of normalized mortality by state with respect to the log of the population.
#          - Groupby county
#          - Groupby state
#          - https://plotly.com/python/line-and-scatter/
#          - Color code the dots by the state.
#
#
# - Member: (60 pts)
#     - **M1.1** Understand the distribution and measures of center for US opioid mortality for 2019 (20 pts)
#          - Import the super dataframe created in Stage I
#          - Create a histogram of Normalized Deaths variable for entire US as a distribution.
#              - https://plotly.com/python/histograms/#histograms-with-gohistogram
#              - https://plotly.com/python/histograms/
#          - Add a vertical line to the histogram representing the ***mean*** Normalized Opioid Death for US.
#              - You should be able to do that with `fig.add_vline()`
#              - https://plotly.com/python/horizontal-vertical-shapes/
#          - Add another line for ***median*** to compare
#     - **M1.2** Understand variable to mortality relationships for 2019 data (40 pts)
#         - Here we codify the column Normalized Deaths (Number of Deaths per 100k Population - `Norm_Deaths`) and store it as a `label` column. (10 pts)
#             - The codification is based on the quantile distribution of the Normalized deaths. i.e.
#                 - Very Low (v_low) - [1.999 - 8.0]
#                 - Low (low) - [8.0 - 11.0]
#                 - High (high) - [11.0 - 16.0]
#                 - Very High (v_high) - [16.0 - 64.0]
#         - Now try the variables you have identified in Stage I and plot them as a second variable to Normalized Mortality in a scatter plot to observe any trends. (20 pts)
#             - For example, if you said population was a indicator, then used population values as the your `y` in scatter plot where `x` is your Normalized Mortality
#         - Describe any trends you observe. (10 pts)
#         - ***Extra credit (additional 20 pts)***
#             - Develop the above approach as a Plotly widget for jupyter, where you can try out the variables dynamically in a simple dashboard. The variables can be in a dropdown.
#             - https://plotly.com/python/figurewidget-app/
#
# **Deliverable**
# - Each member creates separate notebooks for member tasks. Upload all notebooks and reports to Github Repository.
# - Discuss the results as a team. Put together a presentation of your findings, record it via zoom, and upload the recording to canvas.
#
# *PS: Try to use `Plotly` for your charts. Will be useful in Stage V. As plotly graphs are intereactive they are not rendered properly in Github. You can use the approach here to render static images: https://plotly.com/python/static-image-export/. Submission to the repository should contain static images in the notebook.*

# %% [markdown]
# T1.4 Plot a scatter plot graph of normalized mortality by state with respect to the log of the population.
#
# Groupby county
# Groupby state
# https://plotly.com/python/line-and-scatter/
# Color code the dots by the state.

# %% [markdown]
# <b>Importing the required packages</b>

# %%
import pandas as pd
import numpy as np
import plotly.express as px
from IPython.display import Image

# %% [markdown]
# <b>Reading the csv file</b>

# %%
data = pd.read_csv("../../../data/stage_2/1999-2020_Drug_Overdose_By_Category.csv")
data
# Out:
#          Table Names  Notes                County  County Code  Year  \
# 0      1999-2000.txt    NaN  Jefferson County, AL         1073  1999
# 1      1999-2000.txt    NaN  Jefferson County, AL         1073  2000
# 2      1999-2000.txt    NaN  Jefferson County, AL         1073  2000
# 3      1999-2000.txt    NaN  Jefferson County, AL         1073  2000
# 4      1999-2000.txt    NaN     Mobile County, AL         1097  1999
# ...              ...    ...                   ...          ...   ...
# 90902  2005-2009.txt    NaN   Washakie County, WY        56043  2008
# 90903  2005-2009.txt    NaN     Weston County, WY        56045  2005
# 90904  2005-2009.txt    NaN     Weston County, WY        56045  2006
# 90905  2005-2009.txt    NaN     Weston County, WY        56045  2007
# 90906  2005-2009.txt    NaN     Weston County, WY        56045  2008
#
#        Year Code                         Drug/Alcohol Induced Cause  \
# 0           1999  Drug poisonings (overdose) Unintentional (X40-...
# 1           2000  Drug poisonings (overdose) Unintentional (X40-...
# 2           2000       Drug poisonings (overdose) Suicide (X60-X64)
# 3           2000                      All other drug-induced causes
# 4           1999  Drug poisonings (overdose) Unintentional (X40-...
# ...          ...                                                ...
# 90902       2008          All other non-drug and non-alcohol causes
# 90903       2005          All other non-drug and non-alcohol causes
# 90904       2006          All other non-drug and non-alcohol causes
# 90905       2007          All other non-drug and non-alcohol causes
# 90906       2008          All other non-drug and non-alcohol causes
#
#       Drug/Alcohol Induced Cause Code  Deaths  Population  Crude Rate
# 0                                  D1      25      662845         3.8
# 1                                  D1      30      662047         4.5
# 2                                  D2      14      662047  Unreliable
# 3                                  D9      20      662047         3.0
# 4                                  D1      20      399323         5.0
# ...                               ...     ...         ...         ...
# 90902                              O9      89        8229      1081.5
# 90903                              O9      71        6594      1076.7
# 90904                              O9      70        6717      1042.1
# 90905                              O9      79        7033      1123.3
# 90906                              O9      61        7133       855.2
#
# [90907 rows x 11 columns]

# %% [markdown]
# <b>Calculating the mortality rate (Norm_Deaths) by normalizing the deaths by population per 100000</b>

# %%
data["Norm_Deaths"] = (data["Deaths"]/data["Population"]*100000).round()
data
# Out:
#          Table Names  Notes                County  County Code  Year  \
# 0      1999-2000.txt    NaN  Jefferson County, AL         1073  1999
# 1      1999-2000.txt    NaN  Jefferson County, AL         1073  2000
# 2      1999-2000.txt    NaN  Jefferson County, AL         1073  2000
# 3      1999-2000.txt    NaN  Jefferson County, AL         1073  2000
# 4      1999-2000.txt    NaN     Mobile County, AL         1097  1999
# ...              ...    ...                   ...          ...   ...
# 90902  2005-2009.txt    NaN   Washakie County, WY        56043  2008
# 90903  2005-2009.txt    NaN     Weston County, WY        56045  2005
# 90904  2005-2009.txt    NaN     Weston County, WY        56045  2006
# 90905  2005-2009.txt    NaN     Weston County, WY        56045  2007
# 90906  2005-2009.txt    NaN     Weston County, WY        56045  2008
#
#        Year Code                         Drug/Alcohol Induced Cause  \
# 0           1999  Drug poisonings (overdose) Unintentional (X40-...
# 1           2000  Drug poisonings (overdose) Unintentional (X40-...
# 2           2000       Drug poisonings (overdose) Suicide (X60-X64)
# 3           2000                      All other drug-induced causes
# 4           1999  Drug poisonings (overdose) Unintentional (X40-...
# ...          ...                                                ...
# 90902       2008          All other non-drug and non-alcohol causes
# 90903       2005          All other non-drug and non-alcohol causes
# 90904       2006          All other non-drug and non-alcohol causes
# 90905       2007          All other non-drug and non-alcohol causes
# 90906       2008          All other non-drug and non-alcohol causes
#
#       Drug/Alcohol Induced Cause Code  Deaths  Population  Crude Rate  \
# 0                                  D1      25      662845         3.8
# 1                                  D1      30      662047         4.5
# 2                                  D2      14      662047  Unreliable
# 3                                  D9      20      662047         3.0
# 4                                  D1      20      399323         5.0
# ...                               ...     ...         ...         ...
# 90902                              O9      89        8229      1081.5
# 90903                              O9      71        6594      1076.7
# 90904                              O9      70        6717      1042.1
# 90905                              O9      79        7033      1123.3
# 90906                              O9      61        7133       855.2
#
#        Norm_Deaths
# 0              4.0
# 1              5.0
# 2              2.0
# 3              3.0
# 4              5.0
# ...            ...
# 90902       1082.0
# 90903       1077.0
# 90904       1042.0
# 90905       1123.0
# 90906        855.0
#
# [90907 rows x 12 columns]

# %% [markdown]
# https://datascienceparichay.com/article/pandas-split-column-by-delimiter/

# %% [markdown]
# <b>Splitting the County column to separate state information from county and storing in separate columns</b>

# %%
# Spliting the county column using str.split() using the delimeter ","
# expand = True saves the values into different columns. If we do not do it then it will save the values in a list
data[["County", "State"]] = data["County"].str.split(",",expand = True)
# stripping the extra space before the state values
data["State"] = data["State"].str.lstrip()
data
# Out:
#          Table Names  Notes            County  County Code  Year  Year Code  \
# 0      1999-2000.txt    NaN  Jefferson County         1073  1999       1999
# 1      1999-2000.txt    NaN  Jefferson County         1073  2000       2000
# 2      1999-2000.txt    NaN  Jefferson County         1073  2000       2000
# 3      1999-2000.txt    NaN  Jefferson County         1073  2000       2000
# 4      1999-2000.txt    NaN     Mobile County         1097  1999       1999
# ...              ...    ...               ...          ...   ...        ...
# 90902  2005-2009.txt    NaN   Washakie County        56043  2008       2008
# 90903  2005-2009.txt    NaN     Weston County        56045  2005       2005
# 90904  2005-2009.txt    NaN     Weston County        56045  2006       2006
# 90905  2005-2009.txt    NaN     Weston County        56045  2007       2007
# 90906  2005-2009.txt    NaN     Weston County        56045  2008       2008
#
#                               Drug/Alcohol Induced Cause  \
# 0      Drug poisonings (overdose) Unintentional (X40-...
# 1      Drug poisonings (overdose) Unintentional (X40-...
# 2           Drug poisonings (overdose) Suicide (X60-X64)
# 3                          All other drug-induced causes
# 4      Drug poisonings (overdose) Unintentional (X40-...
# ...                                                  ...
# 90902          All other non-drug and non-alcohol causes
# 90903          All other non-drug and non-alcohol causes
# 90904          All other non-drug and non-alcohol causes
# 90905          All other non-drug and non-alcohol causes
# 90906          All other non-drug and non-alcohol causes
#
#       Drug/Alcohol Induced Cause Code  Deaths  Population  Crude Rate  \
# 0                                  D1      25      662845         3.8
# 1                                  D1      30      662047         4.5
# 2                                  D2      14      662047  Unreliable
# 3                                  D9      20      662047         3.0
# 4                                  D1      20      399323         5.0
# ...                               ...     ...         ...         ...
# 90902                              O9      89        8229      1081.5
# 90903                              O9      71        6594      1076.7
# 90904                              O9      70        6717      1042.1
# 90905                              O9      79        7033      1123.3
# 90906                              O9      61        7133       855.2
#
#        Norm_Deaths State
# 0              4.0    AL
# 1              5.0    AL
# 2              2.0    AL
# 3              3.0    AL
# 4              5.0    AL
# ...            ...   ...
# 90902       1082.0    WY
# 90903       1077.0    WY
# 90904       1042.0    WY
# 90905       1123.0    WY
# 90906        855.0    WY
#
# [90907 rows x 13 columns]

# %% [markdown]
# <b> Taking natural log of population columns and storing the values in a different column log_pop</b>

# %%
data["log_pop"] = np.log(data["Population"])
data
# Out:
# C:\Users\Manish\anaconda_new\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#          Table Names  Notes            County  County Code  Year  Year Code  \
# 0      1999-2000.txt    NaN  Jefferson County         1073  1999       1999
# 1      1999-2000.txt    NaN  Jefferson County         1073  2000       2000
# 2      1999-2000.txt    NaN  Jefferson County         1073  2000       2000
# 3      1999-2000.txt    NaN  Jefferson County         1073  2000       2000
# 4      1999-2000.txt    NaN     Mobile County         1097  1999       1999
# ...              ...    ...               ...          ...   ...        ...
# 90902  2005-2009.txt    NaN   Washakie County        56043  2008       2008
# 90903  2005-2009.txt    NaN     Weston County        56045  2005       2005
# 90904  2005-2009.txt    NaN     Weston County        56045  2006       2006
# 90905  2005-2009.txt    NaN     Weston County        56045  2007       2007
# 90906  2005-2009.txt    NaN     Weston County        56045  2008       2008
#
#                               Drug/Alcohol Induced Cause  \
# 0      Drug poisonings (overdose) Unintentional (X40-...
# 1      Drug poisonings (overdose) Unintentional (X40-...
# 2           Drug poisonings (overdose) Suicide (X60-X64)
# 3                          All other drug-induced causes
# 4      Drug poisonings (overdose) Unintentional (X40-...
# ...                                                  ...
# 90902          All other non-drug and non-alcohol causes
# 90903          All other non-drug and non-alcohol causes
# 90904          All other non-drug and non-alcohol causes
# 90905          All other non-drug and non-alcohol causes
# 90906          All other non-drug and non-alcohol causes
#
#       Drug/Alcohol Induced Cause Code  Deaths  Population  Crude Rate  \
# 0                                  D1      25      662845         3.8
# 1                                  D1      30      662047         4.5
# 2                                  D2      14      662047  Unreliable
# 3                                  D9      20      662047         3.0
# 4                                  D1      20      399323         5.0
# ...                               ...     ...         ...         ...
# 90902                              O9      89        8229      1081.5
# 90903                              O9      71        6594      1076.7
# 90904                              O9      70        6717      1042.1
# 90905                              O9      79        7033      1123.3
# 90906                              O9      61        7133       855.2
#
#        Norm_Deaths State    log_pop
# 0              4.0    AL  13.404296
# 1              5.0    AL  13.403092
# 2              2.0    AL  13.403092
# 3              3.0    AL  13.403092
# 4              5.0    AL  12.897526
# ...            ...   ...        ...
# 90902       1082.0    WY   9.015420
# 90903       1077.0    WY   8.793915
# 90904       1042.0    WY   8.812397
# 90905       1123.0    WY   8.858369
# 90906        855.0    WY   8.872487
#
# [90907 rows x 14 columns]

# %% [markdown]
# <b>Checking the describe to see for the above error of divide by zero</b>
#
# <br>
#
# <b>It shows that the errors are in the values of Norm_Deaths and log_pop</b>

# %%
data.describe()
# Out:
#        Notes   County Code          Year     Year Code        Deaths  \
# count    0.0  90907.000000  90907.000000  90907.000000  90907.000000
# mean     NaN  29957.985249   2010.879591   2010.879591    568.447600
# std      NaN  15370.320046      5.832504      5.832504   1842.016231
# min      NaN   1001.000000   1999.000000   1999.000000     10.000000
# 25%      NaN  18029.000000   2006.000000   2006.000000     33.000000
# 50%      NaN  29179.000000   2011.000000   2011.000000    144.000000
# 75%      NaN  42129.000000   2016.000000   2016.000000    415.000000
# max      NaN  56045.000000   2020.000000   2020.000000  78155.000000
#
#          Population  Norm_Deaths       log_pop
# count  9.090700e+04      90907.0  9.090700e+04
# mean   2.415846e+05          inf          -inf
# std    6.103313e+05          NaN           NaN
# min    0.000000e+00          0.0          -inf
# 25%    1.701150e+04         19.0  9.741645e+00
# 50%    5.348800e+04        860.0  1.088721e+01
# 75%    2.019710e+05       1120.0  1.221588e+01
# max    1.017029e+07          inf  1.613498e+01

# %% [markdown]
# Dropping null and infinite values from a row

# %% [markdown]
# <b>Checking for infinite values in Norm_Deaths using np.inf</b>

# %%
data[data["Norm_Deaths"]  == np.inf]
# Out:
#         Table Names  Notes                      County  County Code  Year  \
# 1219  2017-2020.txt    NaN  Valdez-Cordova Census Area         2261  2020
#
#       Year Code                 Drug/Alcohol Induced Cause  \
# 1219       2020  All other non-drug and non-alcohol causes
#
#      Drug/Alcohol Induced Cause Code  Deaths  Population Crude Rate  \
# 1219                              O9      54           0        0.0
#
#       Norm_Deaths State  log_pop
# 1219          inf    AK     -inf

# %% [markdown]
# Dropping the row with the given row index

# %%
# labels indicate the row index, axis =0 indicate row value and inplace = True indicates do it in the main dataset
data.drop(labels = 1219, axis=0,inplace = True)

# %% [markdown]
# <b>Grouping the data by County and State and taking the sum values of Norm_Deaths and log_pop</b>
# <br><br>
# <b>Here, I am grouping the data by State also because there are many counties with same names in different states, so to separate them by state and also to color code by State I am using grouping by on State</b>

# %%
data_county = data.groupby(["County","State"], as_index = False)[["Norm_Deaths","log_pop"]].sum()
data_county
# Out:
#                 County State  Norm_Deaths     log_pop
# 0     Abbeville County    SC      21742.0  202.832324
# 1        Acadia Parish    LA      21114.0  319.603041
# 2      Accomack County    VA      25997.0  208.731288
# 3           Ada County    ID      12651.0  928.333753
# 4         Adair County    IA      28674.0  178.651325
# ...                ...   ...          ...         ...
# 3129       Yuma County    AZ      14209.0  633.553673
# 3130       Yuma County    CO      20452.0  184.157092
# 3131     Zapata County    TX      12736.0  190.474446
# 3132     Zavala County    TX      16000.0  187.525808
# 3133    Ziebach County    SD       9850.0  142.446263
#
# [3134 rows x 4 columns]

# %% [markdown]
# <b>Plotting the plotly plot with Norm_Deaths on x-axis and log_pop on y-axis, color coding by State</b>
# <br><br>
# This shows that there are many dots with same color which shows the county that belongs to that state

# %%
fig = px.scatter(data_county,x= "Norm_Deaths",y = "log_pop",color = "State",title = "Scatter plot of Norm_Deaths vs. Log of Population")
#fig.show()
fig.write_image("stageII_images/scatter_county.png")
img_bytes = fig.to_image(format="png",width=900, height=600)
Image(img_bytes)

# %% [markdown]
# From the plot we can see that there are a large number of cases in different counties when log_pop is between 0 to 900.

# %% [markdown]
# Grouping the data by State and taking the sum values of Norm_Deaths and log_pop again

# %%
data_state = data.groupby("State", as_index = False)[["Norm_Deaths","log_pop"]].sum()
data_state
# Out:
#    State  Norm_Deaths       log_pop
# 0     AK     274866.0   5774.781498
# 1     AL    1545311.0  19387.790922
# 2     AR    1786056.0  17567.896067
# 3     AZ     269747.0  10918.379389
# 4     CA     929387.0  44713.344771
# 5     CO     961588.0  19937.071490
# 6     CT     135558.0   6804.889949
# 7     DC      16647.0   1294.370233
# 8     DE      55972.0   2246.654552
# 9     FL    1397079.0  40307.292987
# 10    GA    3127278.0  42570.969702
# 11    HI      59434.0   2753.856013
# 12    IA    2220446.0  21735.175288
# 13    ID     722197.0  10468.802334
# 14    IL    2226066.0  30809.459711
# 15    IN    1823677.0  28337.533072
# 16    KS    2504029.0  21765.370536
# 17    KY    2667637.0  30321.919824
# 18    LA    1313596.0  19572.621457
# 19    MA     247706.0  11887.374446
# 20    MD     431891.0  13596.946000
# 21    ME     338957.0   6095.653784
# 22    MI    1754880.0  31313.590493
# 23    MN    1712555.0  22387.110849
# 24    MO    2606089.0  29205.250805
# 25    MS    1817165.0  18571.233149
# 26    MT    1140684.0  10979.163405
# 27    NC    2050705.0  37110.734862
# 28    ND    1184704.0   9236.782124
# 29    NE    1944144.0  16171.689483
# 30    NH     185042.0   4806.630712
# 31    NJ     365623.0  16157.041314
# 32    NM     619402.0  12203.889042
# 33    NV     320724.0   6107.514801
# 34    NY    1142844.0  31238.490799
# 35    OH    1788188.0  35654.345959
# 36    OK    1800148.0  20525.155531
# 37    OR     727856.0  15285.909410
# 38    PA    1457169.0  32518.431482
# 39    RI      95326.0   3066.097163
# 40    SC     960759.0  17412.899341
# 41    SD    1393394.0  11861.352946
# 42    TN    2154787.0  29199.088458
# 43    TX    5043098.0  69742.481071
# 44    UT     390867.0   9513.122926
# 45    VA    2764345.0  35725.194268
# 46    VT     252739.0   3852.169241
# 47    WA     696633.0  19163.750387
# 48    WI    1404658.0  22829.472719
# 49    WV    1327576.0  15018.483470
# 50    WY     399685.0   5451.010813

# %%
fig = px.scatter(data_state,x= "Norm_Deaths",y = "log_pop",color = "State")
#fig.show()
fig.write_image("stageII_images/scatter_state.png")
img_bytes = fig.to_image(format="png",width=900, height=600)
Image(img_bytes)

# %% [markdown]
# - The plot shows the values of norm_deaths values of 50 states given the population.
# - From the plot, we can see that there exists a positive relationship between the state mortality rate and population. As population increases, the cases also increases.
