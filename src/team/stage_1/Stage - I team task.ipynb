# %% [markdown]
# # Stage I - Data Understanding and Linking
#
# ## What is the U.S. Opioid Epidemic?
#
# - In the late 1990s, pharmaceutical companies reassured the medical community that patients would not become addicted to opioid pain relievers and healthcare providers began to prescribe them at greater rates.
#
# - Increased prescription of opioid medications led to widespread misuse of both prescription and non-prescription opioids before it became clear that these medications could indeed be highly addictive.
#
# ![opioid](https://www.hhs.gov/opioids/sites/default/files/inline-images/opioids-infographic.png)
#
# Source: https://www.hhs.gov/opioids/about-the-epidemic/index.html

# %% [markdown]
# We are going to study the underlying patterns that exist between opioid related deaths and the different socio-economic, demographic, geographic, and equity related variables that are available for US population. Our goal is to extract such patterns and understand them futher using data science techniques.
#
# In order to achieve that, the project is separated into 5 stages:
#
# - Stage I - Data and Project Understanding,
# - Stage II - Data Modeling,
# - Stage III - Distributions and Hypothesis Testing,
# - Stage IV - Dashboard

# %% [markdown]
# ### Opioid overdose dataset linking
#
# In this stage we utilize multiple publicly available datasets and link them together for analytics. Our goal here is to help identify patterns which contribute to drug overdose deaths. Within this notebook we will explore:
#
# 1. **Creating Index** - Developing an index key for linking datasets
# 2. **Join** - Using join to merge data based on index key.
#
# The notebooks is viewable via any browser.
#
# #### Software used (open source):
#
# - `python` - https://www.python.org/download/releases/3.0/
# - `pandas` - https://pandas.pydata.org/
# - `plotly` - https://plotly.com/

# %% [markdown]
# ### Datasets

# %% [markdown]
# #### 1. Drug Overdose Dataset
#
# The overdose death/cause dataset was obtained from CDC Wonder (https://wonder.cdc.gov/ucd-icd10.html). The dataset is from the Underlying Cause of Death database contains mortality and population counts for all U.S. counties. Data are based on death certificates for U.S. residents. Each death certificate identifies a single underlying cause of death and demographic data.
#
# - From this data we obtained the Drug/Alcohol Induced causes data for 2019 across all counties in US.
# - https://wonder.cdc.gov/wonder/help/ucd.html#Drug/Alcohol%20Induced%20Causes
# - File: `././../../../data/stage_1/Underlying Cause of Death-County-2019.txt`

# %% [markdown]
# #### 2. County Health Rankings
#
# The County Health Rankings provide a snapshot of a community’s health and a starting point for investigating and discussing ways to improve health. The annual Rankings measures vital health factors, including high school graduation rates, obesity, smoking, unemployment, access to healthy foods, the quality of air and water, income inequality, and teen births in nearly every county in America. The dataset provides a snapshot of how health is influenced by where we live, learn, work and play.
#
# - From this data we obtained the measures data for 2019 across all counties in US.
# - https://www.countyhealthrankings.org/
# - Data Dictionary - https://www.countyhealthrankings.org/sites/default/files/DataDictionary_2019.pdf
# - File: `./../../../data/stage_1/County_Health_Ranking.csv`

# %% [markdown]
# #### 3. County Opioid Dispensing Rates
#
# The third dataset in this notebook is the Opoid Dispensing Rate dataset. The dataset has geographic distribution of retail opioid prescriptions dispensed per 100 persons per year from 2006–2019. Rates are classified by the Jenks natural breaks classification method into four groups using the 14-year range of data to determine the class breaks.
#
# - We utilize County Opoid Dispensing Rates for 2019.
# - https://www.cdc.gov/drugoverdose/maps/rxcounty2019.html
# - File: `././../../../data/stage_1/2019-Opioid_Rate.csv`

# %% [markdown]
# ## Tasks:
#
# #### Task 1: (10 pts)
# - **T1.1** Initialize a Github Repository for your project. (10 pts)
#     - Add a description (readme.MD) to your project. See here on how to setup: https://bulldogjob.com/news/449-how-to-write-a-good-readme-for-your-github-project
#
# #### Task 2: (50 pts)
# - Team:
#     - **T2.1** Entire team looks at the datasets and understands the type of variables present in each of the data. (10 pts)
#         - **Deliverable**
#             - Create a report of what the project is about, why this is an important area of work (in your own words), and how can data science help.
#             - Outline how the datasets can be merged together and the common variables.
#
# - Member:
#     - **M2.1** Study prior research in the area. (20 pts)
#         - Read https://link.springer.com/article/10.1007/s40265-017-0846-6
#         - Select one other paper to study in relation to the area. Use https://scholar.google.com/ to search for papers which are related to the goal of this project.
#         - **Deliverable**
#             - Prepare a 1 page summary of what was discovered in these two paper. Significant outcomes, i.e. which variables/determinants are linked to opioid endemic.
#     - **M2.2** Each student member of the team selects 10 variables they think that are important from the available dataset. (20 pts)
#         - **Deliverable**
#             - Prepare a data dictionary (data and datatype - variable dictionary. https://analystanswers.com/what-is-a-data-dictionary-a-simple-thorough-overview/) of the selected variables
#             - Include justification of why you think the variables are important.
#
# Upload the team and member reports to canvas and your Github Repository.
#
# #### Task 3: (50 pts)
# - Team: (20 pts)
#
#     - **T3.1** Create a team notebook to read in the Opioid Mortality data using `pandas` and display the dataframe in a notebook.
#     - **T3.2** Normalize the mortality data by population, i.e. number of deaths per 100,000 population.
#     - **T3.3** Identify issues with the data
#         - Merge issues, missing values, inconsistent values, etc.
#         - Describe solutions to fix it.
#
# - Member: (30 pts)
#     - **M3.1** Merge all the three datasets to create a super datafame. (10 pts)
#         - Display the super dataframe - Its should be (2527, 542) shape
#         - Export it to a csv format.
#     - **M3.2** Identify counties and states (top 10) with the highest opioid mortality rates. (20 pts)
#         - Use mean and median for counties within states to compare (for the state level).
#         - Describe your intution on why the rates are high in these states and counties.
#
# **Deliverable**
# Each member creates separate notebooks for member tasks. Upload all notebooks to Github Repository.

# %% [markdown]
# ### Importing pandas package

# %%
import pandas as pd

# %% [markdown]
# ### Reading csv file using pandas

# %% [markdown]
# * Reading txt file using read_csv() and adding tab as separator

# %%
cause_of_death = pd.read_csv("data/Underlying Cause of Death-County-2019.txt", sep="\t")
cause_of_death
# Out:
#       Notes                 County  County Code  \
# 0       NaN     Autauga County, AL         1001
# 1       NaN     Autauga County, AL         1001
# 2       NaN     Baldwin County, AL         1003
# 3       NaN     Baldwin County, AL         1003
# 4       NaN     Baldwin County, AL         1003
# ...     ...                    ...          ...
# 5536    NaN  Sweetwater County, WY        56037
# 5537    NaN       Teton County, WY        56039
# 5538    NaN       Uinta County, WY        56041
# 5539    NaN       Uinta County, WY        56041
# 5540    NaN    Washakie County, WY        56043
#
#                              Drug/Alcohol Induced Cause  \
# 0     Drug poisonings (overdose) Unintentional (X40-...
# 1          Drug poisonings (overdose) Suicide (X60-X64)
# 2     Drug poisonings (overdose) Unintentional (X40-...
# 3          Drug poisonings (overdose) Suicide (X60-X64)
# 4     Drug poisonings (overdose) Undetermined (Y10-Y14)
# ...                                                 ...
# 5536       Drug poisonings (overdose) Suicide (X60-X64)
# 5537  Drug poisonings (overdose) Unintentional (X40-...
# 5538  Drug poisonings (overdose) Unintentional (X40-...
# 5539  Drug poisonings (overdose) Undetermined (Y10-Y14)
# 5540  Drug poisonings (overdose) Unintentional (X40-...
#
#      Drug/Alcohol Induced Cause Code  Deaths  Population  Crude Rate
# 0                                 D1      69     1087149         6.3
# 1                                 D2      14     1087149  Unreliable
# 2                                 D1     424     3758097        11.3
# 3                                 D2      71     3758097         1.9
# 4                                 D4      19     3758097  Unreliable
# ...                              ...     ...         ...         ...
# 5536                              D2      15      873221  Unreliable
# 5537                              D1      13      440125  Unreliable
# 5538                              D1      51      426347        12.0
# 5539                              D4      10      426347  Unreliable
# 5540                              D1      14      172114  Unreliable
#
# [5541 rows x 8 columns]

# %%
health_ranking = pd.read_csv("data/County_Health_Ranking.csv")
health_ranking
# Out:
#       State FIPS Code  County FIPS Code  5-digit FIPS Code State Abbreviation  \
# 0                   1                 0               1000                 AL
# 1                   1                 1               1001                 AL
# 2                   1                 3               1003                 AL
# 3                   1                 5               1005                 AL
# 4                   1                 7               1007                 AL
# ...               ...               ...                ...                ...
# 3188               56                37              56037                 WY
# 3189               56                39              56039                 WY
# 3190               56                41              56041                 WY
# 3191               56                43              56043                 WY
# 3192               56                45              56045                 WY
#
#                    Name  Release Year  County Ranked (Yes=1/No=0)  \
# 0               Alabama          2019                         NaN
# 1        Autauga County          2019                         1.0
# 2        Baldwin County          2019                         1.0
# 3        Barbour County          2019                         1.0
# 4           Bibb County          2019                         1.0
# ...                 ...           ...                         ...
# 3188  Sweetwater County          2019                         1.0
# 3189       Teton County          2019                         1.0
# 3190       Uinta County          2019                         1.0
# 3191    Washakie County          2019                         1.0
# 3192      Weston County          2019                         1.0
#
#       Premature death raw value  Premature death numerator  \
# 0                   9917.232898                    80440.0
# 1                   8824.057123                      815.0
# 2                   7224.632160                     2827.0
# 3                   9586.165037                      451.0
# 4                  11783.543680                      445.0
# ...                         ...                        ...
# 3188                7497.439952                      495.0
# 3189                3786.128226                      124.0
# 3190                7790.302043                      262.0
# 3191                5504.650970                      108.0
# 3192                4991.168273                       82.0
#
#       Premature death denominator  ...  Male population 18-44 raw value  \
# 0                      13636816.0  ...                              NaN
# 1                        156132.0  ...                              NaN
# 2                        576496.0  ...                              NaN
# 3                         72222.0  ...                              NaN
# 4                         63653.0  ...                              NaN
# ...                           ...  ...                              ...
# 3188                     127427.0  ...                              NaN
# 3189                      66351.0  ...                              NaN
# 3190                      59466.0  ...                              NaN
# 3191                      22335.0  ...                              NaN
# 3192                      19599.0  ...                              NaN
#
#       Male population 45-64 raw value  Male population 65+ raw value  \
# 0                                 NaN                            NaN
# 1                                 NaN                            NaN
# 2                                 NaN                            NaN
# 3                                 NaN                            NaN
# 4                                 NaN                            NaN
# ...                               ...                            ...
# 3188                              NaN                            NaN
# 3189                              NaN                            NaN
# 3190                              NaN                            NaN
# 3191                              NaN                            NaN
# 3192                              NaN                            NaN
#
#       Total male population raw value  Female population 0-17 raw value  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                                 NaN                               NaN
# ...                               ...                               ...
# 3188                              NaN                               NaN
# 3189                              NaN                               NaN
# 3190                              NaN                               NaN
# 3191                              NaN                               NaN
# 3192                              NaN                               NaN
#
#       Female population 18-44 raw value  Female population 45-64 raw value  \
# 0                                   NaN                                NaN
# 1                                   NaN                                NaN
# 2                                   NaN                                NaN
# 3                                   NaN                                NaN
# 4                                   NaN                                NaN
# ...                                 ...                                ...
# 3188                                NaN                                NaN
# 3189                                NaN                                NaN
# 3190                                NaN                                NaN
# 3191                                NaN                                NaN
# 3192                                NaN                                NaN
#
#       Female population 65+ raw value  Total female population raw value  \
# 0                                 NaN                                NaN
# 1                                 NaN                                NaN
# 2                                 NaN                                NaN
# 3                                 NaN                                NaN
# 4                                 NaN                                NaN
# ...                               ...                                ...
# 3188                              NaN                                NaN
# 3189                              NaN                                NaN
# 3190                              NaN                                NaN
# 3191                              NaN                                NaN
# 3192                              NaN                                NaN
#
#       Population growth raw value
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 3188                          NaN
# 3189                          NaN
# 3190                          NaN
# 3191                          NaN
# 3192                          NaN
#
# [3193 rows x 534 columns]

# %% [markdown]
# * Reading file using read_csv() and adding encoding as "unicode escape" to remove encoding issues

# %%
opioid_rate = pd.read_csv("data/2019-Opioid_Rate.csv",encoding='unicode_escape')
opioid_rate
# Out:
#      State             County   FIPS  Opiod_Dispensing_Rate
# 0       AL     Autauga County   1001                  101.3
# 1       AL     Baldwin County   1003                   67.6
# 2       AL     Barbour County   1005                   27.2
# 3       AL        Bibb County   1007                   21.0
# 4       AL      Blount County   1009                   23.7
# ...    ...                ...    ...                    ...
# 3090    WY  Sweetwater County  56037                   70.0
# 3091    WY       Teton County  56039                   54.6
# 3092    WY       Uinta County  56041                   59.5
# 3093    WY    Washakie County  56043                   46.7
# 3094    WY      Weston County  56045                    4.7
#
# [3095 rows x 4 columns]

# %% [markdown]
# * Displaying columns of all dataframes

# %%
cause_of_death.columns
# Out:
# Index(['Notes', 'County', 'County Code', 'Drug/Alcohol Induced Cause',
#        'Drug/Alcohol Induced Cause Code', 'Deaths', 'Population',
#        'Crude Rate'],
#       dtype='object')

# %%
health_ranking.columns
# Out:
# Index(['State FIPS Code', 'County FIPS Code', '5-digit FIPS Code',
#        'State Abbreviation', 'Name', 'Release Year',
#        'County Ranked (Yes=1/No=0)', 'Premature death raw value',
#        'Premature death numerator', 'Premature death denominator',
#        ...
#        'Male population 18-44 raw value', 'Male population 45-64 raw value',
#        'Male population 65+ raw value', 'Total male population raw value',
#        'Female population 0-17 raw value', 'Female population 18-44 raw value',
#        'Female population 45-64 raw value', 'Female population 65+ raw value',
#        'Total female population raw value', 'Population growth raw value'],
#       dtype='object', length=534)

# %%
opioid_rate.columns
# Out:
# Index(['State', 'County', 'FIPS', 'Opiod_Dispensing_Rate'], dtype='object')

# %% [markdown]
# ### Normalize Deaths data by population per 100,000

# %% [markdown]
# * Normalizing deaths data by population per 100000

# %%
cause_of_death["Norm_Deaths"] = (cause_of_death["Deaths"]/cause_of_death["Population"])*100000
cause_of_death
# Out:
#       Notes                 County  County Code  \
# 0       NaN     Autauga County, AL         1001
# 1       NaN     Autauga County, AL         1001
# 2       NaN     Baldwin County, AL         1003
# 3       NaN     Baldwin County, AL         1003
# 4       NaN     Baldwin County, AL         1003
# ...     ...                    ...          ...
# 5536    NaN  Sweetwater County, WY        56037
# 5537    NaN       Teton County, WY        56039
# 5538    NaN       Uinta County, WY        56041
# 5539    NaN       Uinta County, WY        56041
# 5540    NaN    Washakie County, WY        56043
#
#                              Drug/Alcohol Induced Cause  \
# 0     Drug poisonings (overdose) Unintentional (X40-...
# 1          Drug poisonings (overdose) Suicide (X60-X64)
# 2     Drug poisonings (overdose) Unintentional (X40-...
# 3          Drug poisonings (overdose) Suicide (X60-X64)
# 4     Drug poisonings (overdose) Undetermined (Y10-Y14)
# ...                                                 ...
# 5536       Drug poisonings (overdose) Suicide (X60-X64)
# 5537  Drug poisonings (overdose) Unintentional (X40-...
# 5538  Drug poisonings (overdose) Unintentional (X40-...
# 5539  Drug poisonings (overdose) Undetermined (Y10-Y14)
# 5540  Drug poisonings (overdose) Unintentional (X40-...
#
#      Drug/Alcohol Induced Cause Code  Deaths  Population  Crude Rate  \
# 0                                 D1      69     1087149         6.3
# 1                                 D2      14     1087149  Unreliable
# 2                                 D1     424     3758097        11.3
# 3                                 D2      71     3758097         1.9
# 4                                 D4      19     3758097  Unreliable
# ...                              ...     ...         ...         ...
# 5536                              D2      15      873221  Unreliable
# 5537                              D1      13      440125  Unreliable
# 5538                              D1      51      426347        12.0
# 5539                              D4      10      426347  Unreliable
# 5540                              D1      14      172114  Unreliable
#
#       Norm_Deaths
# 0        6.346876
# 1        1.287772
# 2       11.282306
# 3        1.889254
# 4        0.505575
# ...           ...
# 5536     1.717778
# 5537     2.953706
# 5538    11.962087
# 5539     2.345507
# 5540     8.134144
#
# [5541 rows x 9 columns]

# %% [markdown]
# ### **T3.3** Identify issues with the data
# - Merge issues, missing values, inconsistent values, etc.
# - Describe solutions to fix it.

# %% [markdown]
# #### To find null values/missing values in the data, we are using isnull() function on each column.
# #### Then summing up data gives total count of missing values for each column
#
# #### For inconsistent values, we used min() and max().

# %%
cause_of_death.isnull().sum()
# Out:
# Notes                              5541
# County                                0
# County Code                           0
# Drug/Alcohol Induced Cause            0
# Drug/Alcohol Induced Cause Code       0
# Deaths                                0
# Population                            0
# Crude Rate                            0
# Norm_Deaths                           0
# dtype: int64

# %% [markdown]
# #### Missing values:
# * Notes column

# %%
cause_of_death.min(), cause_of_death.max()
# Out:
# (Notes                                                        NaN
#  County                                      Abbeville County, SC
#  County Code                                                 1001
#  Drug/Alcohol Induced Cause         All other drug-induced causes
#  Drug/Alcohol Induced Cause Code                               D1
#  Deaths                                                        10
#  Population                                                 68113
#  Crude Rate                                                   0.0
#  Norm_Deaths                                             0.018188
#  dtype: object,
#  Notes                                                                            NaN
#  County                                                             Zavala County, TX
#  County Code                                                                    56043
#  Drug/Alcohol Induced Cause         Drug poisonings (overdose) Unintentional (X40-...
#  Drug/Alcohol Induced Cause Code                                                   D9
#  Deaths                                                                         13340
#  Population                                                                 207016779
#  Crude Rate                                                                Unreliable
#  Norm_Deaths                                                                56.607603
#  dtype: object)

# %%
cause_of_death["Crude Rate"].min(),cause_of_death["Crude Rate"].max()
# Out:
# ('0.0', 'Unreliable')

# %% [markdown]
# #### Inconsistent values:
# #### Crude Rate
# * Crude Rate column has inconsistency with "Unreliable" values for some rows. Other columns don't have any inconsistent or missing data

# %%
dict(health_ranking.isnull().sum())
# Out:
# {'State FIPS Code': 0,
#  'County FIPS Code': 0,
#  '5-digit FIPS Code': 0,
#  'State Abbreviation': 0,
#  'Name': 0,
#  'Release Year': 0,
#  'County Ranked (Yes=1/No=0)': 51,
#  'Premature death raw value': 61,
#  'Premature death numerator': 61,
#  'Premature death denominator': 61,
#  'Premature death CI low': 61,
#  'Premature death CI high': 61,
#  'Premature death (Black)': 1840,
#  'Premature death (Hispanic)': 2354,
#  'Premature death (White)': 1612,
#  'Poor or fair health raw value': 0,
#  'Poor or fair health numerator': 3193,
#  'Poor or fair health denominator': 3193,
#  'Poor or fair health CI low': 0,
#  'Poor or fair health CI high': 0,
#  'Poor physical health days raw value': 0,
#  'Poor physical health days numerator': 3193,
#  'Poor physical health days denominator': 3193,
#  'Poor physical health days CI low': 0,
#  'Poor physical health days CI high': 0,
#  'Poor mental health days raw value': 0,
#  'Poor mental health days numerator': 3193,
#  'Poor mental health days denominator': 3193,
#  'Poor mental health days CI low': 0,
#  'Poor mental health days CI high': 0,
#  'Low birthweight raw value': 107,
#  'Low birthweight numerator': 107,
#  'Low birthweight denominator': 107,
#  'Low birthweight CI low': 226,
#  'Low birthweight CI high': 226,
#  'Low birthweight (Black)': 1803,
#  'Low birthweight (Hispanic)': 1788,
#  'Low birthweight (White)': 1376,
#  'Adult smoking raw value': 0,
#  'Adult smoking numerator': 3193,
#  'Adult smoking denominator': 3193,
#  'Adult smoking CI low': 0,
#  'Adult smoking CI high': 0,
#  'Adult obesity raw value': 0,
#  'Adult obesity numerator': 0,
#  'Adult obesity denominator': 0,
#  'Adult obesity CI low': 50,
#  'Adult obesity CI high': 50,
#  'Food environment index raw value': 19,
#  'Food environment index numerator': 19,
#  'Food environment index denominator': 0,
#  'Food environment index CI low': 3193,
#  'Food environment index CI high': 3193,
#  'Physical inactivity raw value': 0,
#  'Physical inactivity numerator': 0,
#  'Physical inactivity denominator': 0,
#  'Physical inactivity CI low': 50,
#  'Physical inactivity CI high': 50,
#  'Access to exercise opportunities raw value': 6,
#  'Access to exercise opportunities numerator': 6,
#  'Access to exercise opportunities denominator': 6,
#  'Access to exercise opportunities CI low': 3193,
#  'Access to exercise opportunities CI high': 3193,
#  'Excessive drinking raw value': 0,
#  'Excessive drinking numerator': 3193,
#  'Excessive drinking denominator': 3193,
#  'Excessive drinking CI low': 0,
#  'Excessive drinking CI high': 0,
#  'Alcohol-impaired driving deaths raw value': 33,
#  'Alcohol-impaired driving deaths numerator': 33,
#  'Alcohol-impaired driving deaths denominator': 33,
#  'Alcohol-impaired driving deaths CI low': 59,
#  'Alcohol-impaired driving deaths CI high': 59,
#  'Sexually transmitted infections raw value': 158,
#  'Sexually transmitted infections numerator': 158,
#  'Sexually transmitted infections denominator': 6,
#  'Sexually transmitted infections CI low': 3193,
#  'Sexually transmitted infections CI high': 3193,
#  'Teen births raw value': 144,
#  'Teen births numerator': 144,
#  'Teen births denominator': 144,
#  'Teen births CI low': 263,
#  'Teen births CI high': 263,
#  'Teen births (Black)': 1804,
#  'Teen births (Hispanic)': 1617,
#  'Teen births (White)': 1266,
#  'Uninsured raw value': 1,
#  'Uninsured numerator': 1,
#  'Uninsured denominator': 1,
#  'Uninsured CI low': 1,
#  'Uninsured CI high': 1,
#  'Primary care physicians raw value': 135,
#  'Primary care physicians numerator': 2,
#  'Primary care physicians denominator': 2,
#  'Primary care physicians CI low': 3193,
#  'Primary care physicians CI high': 3193,
#  'Ratio of population to primary care physicians.': 135,
#  'Dentists raw value': 85,
#  'Dentists numerator': 0,
#  'Dentists denominator': 0,
#  'Dentists CI low': 3193,
#  'Dentists CI high': 3193,
#  'Ratio of population to dentists.': 85,
#  'Mental health providers raw value': 252,
#  'Mental health providers numerator': 0,
#  'Mental health providers denominator': 0,
#  'Mental health providers CI low': 3193,
#  'Mental health providers CI high': 3193,
#  'Ratio of population to mental health providers.': 252,
#  'Preventable hospital stays raw value': 38,
#  'Preventable hospital stays numerator': 3193,
#  'Preventable hospital stays denominator': 3193,
#  'Preventable hospital stays CI low': 3193,
#  'Preventable hospital stays CI high': 3193,
#  'Preventable hospital stays (Black)': 1711,
#  'Preventable hospital stays (Hispanic)': 2175,
#  'Preventable hospital stays (White)': 1417,
#  'Mammography screening raw value': 19,
#  'Mammography screening numerator': 3193,
#  'Mammography screening denominator': 3193,
#  'Mammography screening CI low': 3193,
#  'Mammography screening CI high': 3193,
#  'Mammography screening (Black)': 1647,
#  'Mammography screening (Hispanic)': 1811,
#  'Mammography screening (White)': 1226,
#  'Flu vaccinations raw value': 16,
#  'Flu vaccinations numerator': 3193,
#  'Flu vaccinations denominator': 3193,
#  'Flu vaccinations CI low': 3193,
#  'Flu vaccinations CI high': 3193,
#  'Flu vaccinations (Black)': 1341,
#  'Flu vaccinations (Hispanic)': 1355,
#  'Flu vaccinations (White)': 893,
#  'High school graduation raw value': 100,
#  'High school graduation numerator': 300,
#  'High school graduation denominator': 300,
#  'High school graduation CI low': 3193,
#  'High school graduation CI high': 3193,
#  'Some college raw value': 0,
#  'Some college numerator': 0,
#  'Some college denominator': 0,
#  'Some college CI low': 51,
#  'Some college CI high': 51,
#  'Unemployment raw value': 1,
#  'Unemployment numerator': 1,
#  'Unemployment denominator': 1,
#  'Unemployment CI low': 3193,
#  'Unemployment CI high': 3193,
#  'Children in poverty raw value': 1,
#  'Children in poverty numerator': 1,
#  'Children in poverty denominator': 3193,
#  'Children in poverty CI low': 1,
#  'Children in poverty CI high': 1,
#  'Children in poverty (Black)': 1186,
#  'Children in poverty (Hispanic)': 520,
#  'Children in poverty (White)': 358,
#  'Income inequality raw value': 0,
#  'Income inequality numerator': 0,
#  'Income inequality denominator': 0,
#  'Income inequality CI low': 0,
#  'Income inequality CI high': 0,
#  'Children in single-parent households raw value': 1,
#  'Children in single-parent households numerator': 1,
#  'Children in single-parent households denominator': 1,
#  'Children in single-parent households CI low': 1,
#  'Children in single-parent households CI high': 1,
#  'Social associations raw value': 0,
#  'Social associations numerator': 0,
#  'Social associations denominator': 0,
#  'Social associations CI low': 3193,
#  'Social associations CI high': 3193,
#  'Violent crime raw value': 191,
#  'Violent crime numerator': 191,
#  'Violent crime denominator': 191,
#  'Violent crime CI low': 3193,
#  'Violent crime CI high': 3193,
#  'Injury deaths raw value': 103,
#  'Injury deaths numerator': 103,
#  'Injury deaths denominator': 103,
#  'Injury deaths CI low': 103,
#  'Injury deaths CI high': 103,
#  'Air pollution - particulate matter raw value': 36,
#  'Air pollution - particulate matter numerator': 3193,
#  'Air pollution - particulate matter denominator': 3193,
#  'Air pollution - particulate matter CI low': 3193,
#  'Air pollution - particulate matter CI high': 3193,
#  'Drinking water violations raw value': 44,
#  'Drinking water violations numerator': 3193,
#  'Drinking water violations denominator': 3193,
#  'Drinking water violations CI low': 3193,
#  'Drinking water violations CI high': 3193,
#  'Severe housing problems raw value': 0,
#  'Severe housing problems numerator': 0,
#  'Severe housing problems denominator': 0,
#  'Severe housing problems CI low': 1,
#  'Severe housing problems CI high': 1,
#  'Percentage of households with high housing costs': 50,
#  'Percentage of households with overcrowding': 50,
#  'Percentage of households with lack of kitchen or plumbing facilities': 50,
#  'Driving alone to work raw value': 0,
#  'Driving alone to work numerator': 0,
#  'Driving alone to work denominator': 0,
#  'Driving alone to work CI low': 0,
#  'Driving alone to work CI high': 0,
#  'Driving alone to work (Black)': 2014,
#  'Driving alone to work (Hispanic)': 1908,
#  'Driving alone to work (White)': 1531,
#  'Long commute - driving alone raw value': 0,
#  'Long commute - driving alone numerator': 3193,
#  'Long commute - driving alone denominator': 0,
#  'Long commute - driving alone CI low': 0,
#  'Long commute - driving alone CI high': 0,
#  'Life expectancy raw value': 69,
#  'Life expectancy numerator': 3193,
#  'Life expectancy denominator': 3193,
#  'Life expectancy CI low': 69,
#  'Life expectancy CI high': 69,
#  'Life expectancy (Black)': 1853,
#  'Life expectancy (Hispanic)': 1945,
#  'Life expectancy (White)': 1466,
#  'Premature age-adjusted mortality raw value': 61,
#  'Premature age-adjusted mortality numerator': 61,
#  'Premature age-adjusted mortality denominator': 61,
#  'Premature age-adjusted mortality CI low': 61,
#  'Premature age-adjusted mortality CI high': 61,
#  'Premature age-adjusted mortality (Black)': 1839,
#  'Premature age-adjusted mortality (Hispanic)': 2354,
#  'Premature age-adjusted mortality (White)': 1611,
#  'Child mortality raw value': 1222,
#  'Child mortality numerator': 1222,
#  'Child mortality denominator': 1222,
#  'Child mortality CI low': 1222,
#  'Child mortality CI high': 1222,
#  'Child mortality (Black)': 2684,
#  'Child mortality (Hispanic)': 2818,
#  'Child mortality (White)': 2571,
#  'Infant mortality raw value': 1882,
#  'Infant mortality numerator': 1223,
#  'Infant mortality denominator': 1223,
#  'Infant mortality CI low': 1882,
#  'Infant mortality CI high': 1882,
#  'Infant mortality (Black)': 2842,
#  'Infant mortality (Hispanic)': 2960,
#  'Infant mortality (White)': 2786,
#  'Frequent physical distress raw value': 0,
#  'Frequent physical distress numerator': 3193,
#  'Frequent physical distress denominator': 3193,
#  'Frequent physical distress CI low': 0,
#  'Frequent physical distress CI high': 0,
#  'Frequent mental distress raw value': 0,
#  'Frequent mental distress numerator': 3193,
#  'Frequent mental distress denominator': 3193,
#  'Frequent mental distress CI low': 0,
#  'Frequent mental distress CI high': 0,
#  'Diabetes prevalence raw value': 0,
#  'Diabetes prevalence numerator': 0,
#  'Diabetes prevalence denominator': 0,
#  'Diabetes prevalence CI low': 50,
#  'Diabetes prevalence CI high': 50,
#  'HIV prevalence raw value': 718,
#  'HIV prevalence numerator': 718,
#  'HIV prevalence denominator': 718,
#  'HIV prevalence CI low': 3193,
#  'HIV prevalence CI high': 3193,
#  'Food insecurity raw value': 0,
#  'Food insecurity numerator': 0,
#  'Food insecurity denominator': 3193,
#  'Food insecurity CI low': 3193,
#  'Food insecurity CI high': 3193,
#  'Limited access to healthy foods raw value': 19,
#  'Limited access to healthy foods numerator': 19,
#  'Limited access to healthy foods denominator': 0,
#  'Limited access to healthy foods CI low': 3193,
#  'Limited access to healthy foods CI high': 3193,
#  'Drug overdose deaths raw value': 1422,
#  'Drug overdose deaths numerator': 1422,
#  'Drug overdose deaths denominator': 1422,
#  'Drug overdose deaths CI low': 1422,
#  'Drug overdose deaths CI high': 1422,
#  'Motor vehicle crash deaths raw value': 442,
#  'Motor vehicle crash deaths numerator': 442,
#  'Motor vehicle crash deaths denominator': 442,
#  'Motor vehicle crash deaths CI low': 442,
#  'Motor vehicle crash deaths CI high': 442,
#  'Insufficient sleep raw value': 0,
#  'Insufficient sleep numerator': 3193,
#  'Insufficient sleep denominator': 3193,
#  'Insufficient sleep CI low': 0,
#  'Insufficient sleep CI high': 0,
#  'Uninsured adults raw value': 1,
#  'Uninsured adults numerator': 1,
#  'Uninsured adults denominator': 1,
#  'Uninsured adults CI low': 1,
#  'Uninsured adults CI high': 1,
#  'Uninsured children raw value': 1,
#  'Uninsured children numerator': 1,
#  'Uninsured children denominator': 1,
#  'Uninsured children CI low': 1,
#  'Uninsured children CI high': 1,
#  'Other primary care providers raw value': 26,
#  'Other primary care providers numerator': 0,
#  'Other primary care providers denominator': 0,
#  'Other primary care providers CI low': 3193,
#  'Other primary care providers CI high': 3193,
#  'Ratio of population to primary care providers other than physicians.': 26,
#  'Disconnected youth raw value': 1730,
#  'Disconnected youth numerator': 1730,
#  'Disconnected youth denominator': 1730,
#  'Disconnected youth CI low': 1730,
#  'Disconnected youth CI high': 1730,
#  'Median household income raw value': 1,
#  'Median household income numerator': 3193,
#  'Median household income denominator': 3193,
#  'Median household income CI low': 1,
#  'Median household income CI high': 1,
#  'Median household income (Black)': 1257,
#  'Median household income (Hispanic)': 742,
#  'Median household income (White)': 456,
#  'Children eligible for free or reduced price lunch raw value': 125,
#  'Children eligible for free or reduced price lunch numerator': 125,
#  'Children eligible for free or reduced price lunch denominator': 125,
#  'Children eligible for free or reduced price lunch CI low': 3193,
#  'Children eligible for free or reduced price lunch CI high': 3193,
#  'Residential segregation - Black/White raw value': 1083,
#  'Residential segregation - Black/White numerator': 3193,
#  'Residential segregation - Black/White denominator': 3193,
#  'Residential segregation - Black/White CI low': 3193,
#  'Residential segregation - Black/White CI high': 3193,
#  'Residential segregation - non-white/white raw value': 347,
#  'Residential segregation - non-white/white numerator': 3193,
#  'Residential segregation - non-white/white denominator': 3193,
#  'Residential segregation - non-white/white CI low': 3193,
#  'Residential segregation - non-white/white CI high': 3193,
#  'Homicides raw value': 1870,
#  'Homicides numerator': 1870,
#  'Homicides denominator': 1870,
#  'Homicides CI low': 1870,
#  'Homicides CI high': 1870,
#  'Firearm fatalities raw value': 933,
#  'Firearm fatalities numerator': 933,
#  'Firearm fatalities denominator': 933,
#  'Firearm fatalities CI low': 933,
#  'Firearm fatalities CI high': 933,
#  'Homeownership raw value': 0,
#  'Homeownership numerator': 0,
#  'Homeownership denominator': 0,
#  'Homeownership CI low': 0,
#  'Homeownership CI high': 0,
#  'Severe housing cost burden raw value': 1,
#  'Severe housing cost burden numerator': 1,
#  'Severe housing cost burden denominator': 1,
#  'Severe housing cost burden CI low': 1,
#  'Severe housing cost burden CI high': 1,
#  'Population raw value': 0,
#  'Population numerator': 3193,
#  'Population denominator': 3193,
#  'Population CI low': 3193,
#  'Population CI high': 3193,
#  '% below 18 years of age raw value': 0,
#  '% below 18 years of age numerator': 3193,
#  '% below 18 years of age denominator': 3193,
#  '% below 18 years of age CI low': 3193,
#  '% below 18 years of age CI high': 3193,
#  '% 65 and older raw value': 0,
#  '% 65 and older numerator': 3193,
#  '% 65 and older denominator': 3193,
#  '% 65 and older CI low': 3193,
#  '% 65 and older CI high': 3193,
#  '% Non-Hispanic African American raw value': 0,
#  '% Non-Hispanic African American numerator': 0,
#  '% Non-Hispanic African American denominator': 0,
#  '% Non-Hispanic African American CI low': 3193,
#  '% Non-Hispanic African American CI high': 3193,
#  '% American Indian and Alaskan Native raw value': 0,
#  '% American Indian and Alaskan Native numerator': 0,
#  '% American Indian and Alaskan Native denominator': 0,
#  '% American Indian and Alaskan Native CI low': 3193,
#  '% American Indian and Alaskan Native CI high': 3193,
#  '% Asian raw value': 0,
#  '% Asian numerator': 0,
#  '% Asian denominator': 0,
#  '% Asian CI low': 3193,
#  '% Asian CI high': 3193,
#  '% Native Hawaiian/Other Pacific Islander raw value': 0,
#  '% Native Hawaiian/Other Pacific Islander numerator': 0,
#  '% Native Hawaiian/Other Pacific Islander denominator': 0,
#  '% Native Hawaiian/Other Pacific Islander CI low': 3193,
#  '% Native Hawaiian/Other Pacific Islander CI high': 3193,
#  '% Hispanic raw value': 0,
#  '% Hispanic numerator': 0,
#  '% Hispanic denominator': 0,
#  '% Hispanic CI low': 3193,
#  '% Hispanic CI high': 3193,
#  '% Non-Hispanic white raw value': 0,
#  '% Non-Hispanic white numerator': 0,
#  '% Non-Hispanic white denominator': 0,
#  '% Non-Hispanic white CI low': 3193,
#  '% Non-Hispanic white CI high': 3193,
#  '% not proficient in English raw value': 0,
#  '% not proficient in English numerator': 0,
#  '% not proficient in English denominator': 0,
#  '% not proficient in English CI low': 156,
#  '% not proficient in English CI high': 156,
#  '% Females raw value': 0,
#  '% Females numerator': 3193,
#  '% Females denominator': 3193,
#  '% Females CI low': 3193,
#  '% Females CI high': 3193,
#  '% Rural raw value': 7,
#  '% Rural numerator': 7,
#  '% Rural denominator': 7,
#  '% Rural CI low': 3193,
#  '% Rural CI high': 3193,
#  'Communicable disease raw value': 3120,
#  'Communicable disease numerator': 3120,
#  'Communicable disease denominator': 3120,
#  'Communicable disease CI low': 3193,
#  'Communicable disease CI high': 3193,
#  'Self-inflicted injury hospitalizations raw value': 3123,
#  'Self-inflicted injury hospitalizations numerator': 3123,
#  'Self-inflicted injury hospitalizations denominator': 3193,
#  'Self-inflicted injury hospitalizations CI low': 3123,
#  'Self-inflicted injury hospitalizations CI high': 3123,
#  'Cancer incidence raw value': 3120,
#  'Cancer incidence numerator': 3120,
#  'Cancer incidence denominator': 3120,
#  'Cancer incidence CI low': 3120,
#  'Cancer incidence CI high': 3120,
#  'Coronary heart disease hospitalizations raw value': 3122,
#  'Coronary heart disease hospitalizations numerator': 3122,
#  'Coronary heart disease hospitalizations denominator': 3193,
#  'Coronary heart disease hospitalizations CI low': 3193,
#  'Coronary heart disease hospitalizations CI high': 3193,
#  'Cerebrovascular disease hospitalizations raw value': 3122,
#  'Cerebrovascular disease hospitalizations numerator': 3122,
#  'Cerebrovascular disease hospitalizations denominator': 3193,
#  'Cerebrovascular disease hospitalizations CI low': 3193,
#  'Cerebrovascular disease hospitalizations CI high': 3193,
#  'Smoking during pregnancy raw value': 3120,
#  'Smoking during pregnancy numerator': 3120,
#  'Smoking during pregnancy denominator': 3120,
#  'Smoking during pregnancy CI low': 3193,
#  'Smoking during pregnancy CI high': 3193,
#  'Drug arrests raw value': 3121,
#  'Drug arrests numerator': 3193,
#  'Drug arrests denominator': 3193,
#  'Drug arrests CI low': 3193,
#  'Drug arrests CI high': 3193,
#  'Opioid hospital visits raw value': 3121,
#  'Opioid hospital visits numerator': 3121,
#  'Opioid hospital visits denominator': 3120,
#  'Opioid hospital visits CI low': 3121,
#  'Opioid hospital visits CI high': 3121,
#  'Alcohol-related hospitalizations raw value': 3130,
#  'Alcohol-related hospitalizations numerator': 3130,
#  'Alcohol-related hospitalizations denominator': 3193,
#  'Alcohol-related hospitalizations CI low': 3193,
#  'Alcohol-related hospitalizations CI high': 3193,
#  'Motor vehicle crash occupancy rate raw value': 3120,
#  'Motor vehicle crash occupancy rate numerator': 3120,
#  'Motor vehicle crash occupancy rate denominator': 3120,
#  'Motor vehicle crash occupancy rate CI low': 3193,
#  'Motor vehicle crash occupancy rate CI high': 3193,
#  'On-road motor vehicle crash-related ER visits raw value': 3120,
#  'On-road motor vehicle crash-related ER visits numerator': 3120,
#  'On-road motor vehicle crash-related ER visits denominator': 3193,
#  'On-road motor vehicle crash-related ER visits CI low': 3120,
#  'On-road motor vehicle crash-related ER visits CI high': 3120,
#  'Off-road motor vehicle crash-related ER visits raw value': 3121,
#  'Off-road motor vehicle crash-related ER visits numerator': 3121,
#  'Off-road motor vehicle crash-related ER visits denominator': 3193,
#  'Off-road motor vehicle crash-related ER visits CI low': 3121,
#  'Off-road motor vehicle crash-related ER visits CI high': 3121,
#  'Childhood immunizations raw value': 3120,
#  'Childhood immunizations numerator': 3193,
#  'Childhood immunizations denominator': 3193,
#  'Childhood immunizations CI low': 3193,
#  'Childhood immunizations CI high': 3193,
#  'Reading proficiency raw value': 3120,
#  'Reading proficiency numerator': 3120,
#  'Reading proficiency denominator': 3120,
#  'Reading proficiency CI low': 3193,
#  'Reading proficiency CI high': 3193,
#  'W-2 enrollment raw value': 3120,
#  'W-2 enrollment numerator': 3193,
#  'W-2 enrollment denominator': 3193,
#  'W-2 enrollment CI low': 3193,
#  'W-2 enrollment CI high': 3193,
#  'Poverty raw value': 3120,
#  'Poverty numerator': 3120,
#  'Poverty denominator': 3193,
#  'Poverty CI low': 3120,
#  'Poverty CI high': 3120,
#  'Older adults living alone raw value': 3120,
#  'Older adults living alone numerator': 3120,
#  'Older adults living alone denominator': 3120,
#  'Older adults living alone CI low': 3193,
#  'Older adults living alone CI high': 3193,
#  'Hate crimes raw value': 3180,
#  'Hate crimes numerator': 3180,
#  'Hate crimes denominator': 3120,
#  'Hate crimes CI low': 3193,
#  'Hate crimes CI high': 3193,
#  'Child abuse raw value': 3120,
#  'Child abuse numerator': 3120,
#  'Child abuse denominator': 3120,
#  'Child abuse CI low': 3193,
#  'Child abuse CI high': 3193,
#  'Injury hospitalizations raw value': 3120,
#  'Injury hospitalizations numerator': 3120,
#  'Injury hospitalizations denominator': 3193,
#  'Injury hospitalizations CI low': 3120,
#  'Injury hospitalizations CI high': 3120,
#  'Fall fatalities 65+ raw value': 3128,
#  'Fall fatalities 65+ numerator': 3128,
#  'Fall fatalities 65+ denominator': 3120,
#  'Fall fatalities 65+ CI low': 3128,
#  'Fall fatalities 65+ CI high': 3128,
#  'Year structure built raw value': 3120,
#  'Year structure built numerator': 3120,
#  'Year structure built denominator': 3120,
#  'Year structure built CI low': 3193,
#  'Year structure built CI high': 3193,
#  'Male population 0-17 raw value': 3120,
#  'Male population 18-44 raw value': 3120,
#  'Male population 45-64 raw value': 3120,
#  'Male population 65+ raw value': 3120,
#  'Total male population raw value': 3120,
#  'Female population 0-17 raw value': 3120,
#  'Female population 18-44 raw value': 3120,
#  'Female population 45-64 raw value': 3120,
#  'Female population 65+ raw value': 3120,
#  'Total female population raw value': 3120,
#  'Population growth raw value': 3120}

# %%
dict(health_ranking.min())
# Out:
# {'State FIPS Code': 1,
#  'County FIPS Code': 0,
#  '5-digit FIPS Code': 1000,
#  'State Abbreviation': 'AK',
#  'Name': 'Abbeville County',
#  'Release Year': 2019,
#  'County Ranked (Yes=1/No=0)': 0.0,
#  'Premature death raw value': 2610.690433,
#  'Premature death numerator': 20.0,
#  'Premature death denominator': 2175.0,
#  'Premature death CI low': 1744.238075,
#  'Premature death CI high': 3136.482571,
#  'Premature death (Black)': 3395.803526,
#  'Premature death (Hispanic)': 1790.832601,
#  'Premature death (White)': 2594.916115,
#  'Poor or fair health raw value': 0.08289167,
#  'Poor or fair health numerator': nan,
#  'Poor or fair health denominator': nan,
#  'Poor or fair health CI low': 0.08028131,
#  'Poor or fair health CI high': 0.085673145,
#  'Poor physical health days raw value': 2.323510942,
#  'Poor physical health days numerator': nan,
#  'Poor physical health days denominator': nan,
#  'Poor physical health days CI low': 2.237868812,
#  'Poor physical health days CI high': 2.415157965,
#  'Poor mental health days raw value': 2.439653597,
#  'Poor mental health days numerator': nan,
#  'Poor mental health days denominator': nan,
#  'Poor mental health days CI low': 2.274506325,
#  'Poor mental health days CI high': 2.612534655,
#  'Low birthweight raw value': 0.026455027,
#  'Low birthweight numerator': 10.0,
#  'Low birthweight denominator': 85.0,
#  'Low birthweight CI low': 0.02207537,
#  'Low birthweight CI high': 0.049757053,
#  'Low birthweight (Black)': 0.049382716,
#  'Low birthweight (Hispanic)': 0.035714286,
#  'Low birthweight (White)': 0.036553525,
#  'Adult smoking raw value': 0.067354328,
#  'Adult smoking numerator': nan,
#  'Adult smoking denominator': nan,
#  'Adult smoking CI low': 0.064614969,
#  'Adult smoking CI high': 0.070318865,
#  'Adult obesity raw value': 0.136,
#  'Adult obesity numerator': 20,
#  'Adult obesity denominator': 69.44444444,
#  'Adult obesity CI low': 0.109,
#  'Adult obesity CI high': 0.162,
#  'Food environment index raw value': 0.0,
#  'Food environment index numerator': 0.0,
#  'Food environment index denominator': 0.037,
#  'Food environment index CI low': nan,
#  'Food environment index CI high': nan,
#  'Physical inactivity raw value': 0.084,
#  'Physical inactivity numerator': 15,
#  'Physical inactivity denominator': 67.56756757,
#  'Physical inactivity CI low': 0.061,
#  'Physical inactivity CI high': 0.105,
#  'Access to exercise opportunities raw value': 0.0,
#  'Access to exercise opportunities numerator': 0.0,
#  'Access to exercise opportunities denominator': 82.0,
#  'Access to exercise opportunities CI low': nan,
#  'Access to exercise opportunities CI high': nan,
#  'Excessive drinking raw value': 0.092651558,
#  'Excessive drinking numerator': nan,
#  'Excessive drinking denominator': nan,
#  'Excessive drinking CI low': 0.08776246,
#  'Excessive drinking CI high': 0.096974273,
#  'Alcohol-impaired driving deaths raw value': 0.0,
#  'Alcohol-impaired driving deaths numerator': 0.0,
#  'Alcohol-impaired driving deaths denominator': 1.0,
#  'Alcohol-impaired driving deaths CI low': 0.0,
#  'Alcohol-impaired driving deaths CI high': 0.063688428,
#  'Sexually transmitted infections raw value': 40.1,
#  'Sexually transmitted infections numerator': 4.0,
#  'Sexually transmitted infections denominator': 89.0,
#  'Sexually transmitted infections CI low': nan,
#  'Sexually transmitted infections CI high': nan,
#  'Teen births raw value': 2.394970562,
#  'Teen births numerator': 10.0,
#  'Teen births denominator': 180.0,
#  'Teen births CI low': 1.9,
#  'Teen births CI high': 2.9,
#  'Teen births (Black)': 3.65230095,
#  'Teen births (Hispanic)': 5.487547488,
#  'Teen births (White)': 1.138703816,
#  'Uninsured raw value': 0.020682014,
#  'Uninsured numerator': 22.0,
#  'Uninsured denominator': 104.0,
#  'Uninsured CI low': 0.018299036,
#  'Uninsured CI high': 0.023064993,
#  'Primary care physicians raw value': 0.0,
#  'Primary care physicians numerator': 0.0,
#  'Primary care physicians denominator': 88.0,
#  'Primary care physicians CI low': nan,
#  'Primary care physicians CI high': nan,
#  'Ratio of population to primary care physicians.': -1971.0,
#  'Dentists raw value': 0.0,
#  'Dentists numerator': 0,
#  'Dentists denominator': 88,
#  'Dentists CI low': nan,
#  'Dentists CI high': nan,
#  'Ratio of population to dentists.': -3936.0,
#  'Mental health providers raw value': 0.0,
#  'Mental health providers numerator': 0,
#  'Mental health providers denominator': 88,
#  'Mental health providers CI low': nan,
#  'Mental health providers CI high': nan,
#  'Ratio of population to mental health providers.': -940.0,
#  'Preventable hospital stays raw value': 471.0,
#  'Preventable hospital stays numerator': nan,
#  'Preventable hospital stays denominator': nan,
#  'Preventable hospital stays CI low': nan,
#  'Preventable hospital stays CI high': nan,
#  'Preventable hospital stays (Black)': 402.0,
#  'Preventable hospital stays (Hispanic)': 298.0,
#  'Preventable hospital stays (White)': 631.0,
#  'Mammography screening raw value': 0.07,
#  'Mammography screening numerator': nan,
#  'Mammography screening denominator': nan,
#  'Mammography screening CI low': nan,
#  'Mammography screening CI high': nan,
#  'Mammography screening (Black)': 0.1,
#  'Mammography screening (Hispanic)': 0.08,
#  'Mammography screening (White)': 0.13,
#  'Flu vaccinations raw value': 0.03,
#  'Flu vaccinations numerator': nan,
#  'Flu vaccinations denominator': nan,
#  'Flu vaccinations CI low': nan,
#  'Flu vaccinations CI high': nan,
#  'Flu vaccinations (Black)': 0.03,
#  'Flu vaccinations (Hispanic)': 0.02,
#  'Flu vaccinations (White)': 0.09,
#  'High school graduation raw value': 0.2564,
#  'High school graduation numerator': 2.0,
#  'High school graduation denominator': 3.0,
#  'High school graduation CI low': nan,
#  'High school graduation CI high': nan,
#  'Some college raw value': 0.167562122,
#  'Some college numerator': 7,
#  'Some college denominator': 12,
#  'Some college CI low': 0.0,
#  'Some college CI high': 0.211703042,
#  'Unemployment raw value': 0.016241705,
#  'Unemployment numerator': 5.0,
#  'Unemployment denominator': 100.0,
#  'Unemployment CI low': nan,
#  'Unemployment CI high': nan,
#  'Children in poverty raw value': 0.027,
#  'Children in poverty numerator': 11.0,
#  'Children in poverty denominator': nan,
#  'Children in poverty CI low': 0.019851064,
#  'Children in poverty CI high': 0.034148936,
#  'Children in poverty (Black)': 0.003610108,
#  'Children in poverty (Hispanic)': 0.003610108,
#  'Children in poverty (White)': 0.000427899,
#  'Income inequality raw value': 2.556075485,
#  'Income inequality numerator': 46701,
#  'Income inequality denominator': 7563,
#  'Income inequality CI low': 0.0,
#  'Income inequality CI high': 2.739174408,
#  'Children in single-parent households raw value': 0.0,
#  'Children in single-parent households numerator': 0.0,
#  'Children in single-parent households denominator': 7.0,
#  'Children in single-parent households CI low': 0.0,
#  'Children in single-parent households CI high': 0.040408163,
#  'Social associations raw value': 0.0,
#  'Social associations numerator': 0,
#  'Social associations denominator': 88,
#  'Social associations CI low': nan,
#  'Social associations CI high': nan,
#  'Violent crime raw value': 0.0,
#  'Violent crime numerator': 0.0,
#  'Violent crime denominator': 110.5,
#  'Violent crime CI low': nan,
#  'Violent crime CI high': nan,
#  'Injury deaths raw value': 25.5907191,
#  'Injury deaths numerator': 10.0,
#  'Injury deaths denominator': 4123.0,
#  'Injury deaths CI low': 13.2,
#  'Injury deaths CI high': 32.3,
#  'Air pollution - particulate matter raw value': 3.0,
#  'Air pollution - particulate matter numerator': nan,
#  'Air pollution - particulate matter denominator': nan,
#  'Air pollution - particulate matter CI low': nan,
#  'Air pollution - particulate matter CI high': nan,
#  'Drinking water violations raw value': 0.0,
#  'Drinking water violations numerator': nan,
#  'Drinking water violations denominator': nan,
#  'Drinking water violations CI low': nan,
#  'Drinking water violations CI high': nan,
#  'Severe housing problems raw value': 0.030379747,
#  'Severe housing problems numerator': 8,
#  'Severe housing problems denominator': 45,
#  'Severe housing problems CI low': 0.0,
#  'Severe housing problems CI high': 0.058760118,
#  'Percentage of households with high housing costs': 0.011842729,
#  'Percentage of households with overcrowding': 0.0,
#  'Percentage of households with lack of kitchen or plumbing facilities': 0.0,
#  'Driving alone to work raw value': 0.045849421,
#  'Driving alone to work numerator': 21,
#  'Driving alone to work denominator': 39,
#  'Driving alone to work CI low': 0.025882698,
#  'Driving alone to work CI high': 0.062365826,
#  'Driving alone to work (Black)': 0.11487058,
#  'Driving alone to work (Hispanic)': 0.072289157,
#  'Driving alone to work (White)': 0.099562809,
#  'Long commute - driving alone raw value': 0.0,
#  'Long commute - driving alone numerator': nan,
#  'Long commute - driving alone denominator': 21,
#  'Long commute - driving alone CI low': 0.0,
#  'Long commute - driving alone CI high': 0.02493743,
#  'Life expectancy raw value': 62.44161235,
#  'Life expectancy numerator': nan,
#  'Life expectancy denominator': nan,
#  'Life expectancy CI low': 57.88222611,
#  'Life expectancy CI high': 64.27792432,
#  'Life expectancy (Black)': 64.77082999,
#  'Life expectancy (Hispanic)': 70.43339823,
#  'Life expectancy (White)': 63.41188131,
#  'Premature age-adjusted mortality raw value': 123.6,
#  'Premature age-adjusted mortality numerator': 20.0,
#  'Premature age-adjusted mortality denominator': 2175.0,
#  'Premature age-adjusted mortality CI low': 89.1,
#  'Premature age-adjusted mortality CI high': 157.2,
#  'Premature age-adjusted mortality (Black)': 180.6933467,
#  'Premature age-adjusted mortality (Hispanic)': 93.07657403,
#  'Premature age-adjusted mortality (White)': 139.6976074,
#  'Child mortality raw value': 16.92405331,
#  'Child mortality numerator': 10.0,
#  'Child mortality denominator': 4413.0,
#  'Child mortality CI low': 9.6,
#  'Child mortality CI high': 23.1,
#  'Child mortality (Black)': 37.10758727,
#  'Child mortality (Hispanic)': 18.97153216,
#  'Child mortality (White)': 13.85728456,
#  'Infant mortality raw value': 2.321843186,
#  'Infant mortality numerator': 10.0,
#  'Infant mortality denominator': 623.0,
#  'Infant mortality CI low': 1.5,
#  'Infant mortality CI high': 3.2,
#  'Infant mortality (Black)': 4.300452788,
#  'Infant mortality (Hispanic)': 2.478363493,
#  'Infant mortality (White)': 2.023165242,
#  'Frequent physical distress raw value': 0.069369866,
#  'Frequent physical distress numerator': nan,
#  'Frequent physical distress denominator': nan,
#  'Frequent physical distress CI low': 0.067555241,
#  'Frequent physical distress CI high': 0.071293054,
#  'Frequent mental distress raw value': 0.080345573,
#  'Frequent mental distress numerator': nan,
#  'Frequent mental distress denominator': nan,
#  'Frequent mental distress CI low': 0.072275661,
#  'Frequent mental distress CI high': 0.082697154,
#  'Diabetes prevalence raw value': 0.033,
#  'Diabetes prevalence numerator': 7,
#  'Diabetes prevalence denominator': 72.91666667,
#  'Diabetes prevalence CI low': 0.025,
#  'Diabetes prevalence CI high': 0.045,
#  'HIV prevalence raw value': 10.4,
#  'HIV prevalence numerator': 5.0,
#  'HIV prevalence denominator': 536.0,
#  'HIV prevalence CI low': nan,
#  'HIV prevalence CI high': nan,
#  'Food insecurity raw value': 0.037,
#  'Food insecurity numerator': 10,
#  'Food insecurity denominator': nan,
#  'Food insecurity CI low': nan,
#  'Food insecurity CI high': nan,
#  'Limited access to healthy foods raw value': 0.0,
#  'Limited access to healthy foods numerator': 0.0,
#  'Limited access to healthy foods denominator': 82,
#  'Limited access to healthy foods CI low': nan,
#  'Limited access to healthy foods CI high': nan,
#  'Drug overdose deaths raw value': 3.212149132,
#  'Drug overdose deaths numerator': 10.0,
#  'Drug overdose deaths denominator': 19831.0,
#  'Drug overdose deaths CI low': 2.2,
#  'Drug overdose deaths CI high': 4.0,
#  'Motor vehicle crash deaths raw value': 2.806816524,
#  'Motor vehicle crash deaths numerator': 10.0,
#  'Motor vehicle crash deaths denominator': 13033.0,
#  'Motor vehicle crash deaths CI low': 1.8,
#  'Motor vehicle crash deaths CI high': 3.1,
#  'Insufficient sleep raw value': 0.230283478,
#  'Insufficient sleep numerator': nan,
#  'Insufficient sleep denominator': nan,
#  'Insufficient sleep CI low': 0.221264517,
#  'Insufficient sleep CI high': 0.239467897,
#  'Uninsured adults raw value': 0.025434074,
#  'Uninsured adults numerator': 12.0,
#  'Uninsured adults denominator': 57.0,
#  'Uninsured adults CI low': 0.021859606,
#  'Uninsured adults CI high': 0.029008542,
#  'Uninsured children raw value': 0.00764677,
#  'Uninsured children numerator': 5.0,
#  'Uninsured children denominator': 47.0,
#  'Uninsured children CI low': 0.005263792,
#  'Uninsured children CI high': 0.010029749,
#  'Other primary care providers raw value': 0.0,
#  'Other primary care providers numerator': 0,
#  'Other primary care providers denominator': 88,
#  'Other primary care providers CI low': nan,
#  'Other primary care providers CI high': nan,
#  'Ratio of population to primary care providers other than physicians.': -3936.0,
#  'Disconnected youth raw value': 0.009538951,
#  'Disconnected youth numerator': 40.0,
#  'Disconnected youth denominator': 217.0,
#  'Disconnected youth CI low': 0.004163398,
#  'Disconnected youth CI high': 0.014914504,
#  'Median household income raw value': 22679.0,
#  'Median household income numerator': nan,
#  'Median household income denominator': nan,
#  'Median household income CI low': 20037.46809,
#  'Median household income CI high': 25320.53192,
#  'Median household income (Black)': 6903.0,
#  'Median household income (Hispanic)': 7917.0,
#  'Median household income (White)': 18750.0,
#  'Children eligible for free or reduced price lunch raw value': 0.0,
#  'Children eligible for free or reduced price lunch numerator': 0.0,
#  'Children eligible for free or reduced price lunch denominator': 21.0,
#  'Children eligible for free or reduced price lunch CI low': nan,
#  'Children eligible for free or reduced price lunch CI high': nan,
#  'Residential segregation - Black/White raw value': 0.632824937,
#  'Residential segregation - Black/White numerator': nan,
#  'Residential segregation - Black/White denominator': nan,
#  'Residential segregation - Black/White CI low': nan,
#  'Residential segregation - Black/White CI high': nan,
#  'Residential segregation - non-white/white raw value': 0.045076084,
#  'Residential segregation - non-white/white numerator': nan,
#  'Residential segregation - non-white/white denominator': nan,
#  'Residential segregation - non-white/white CI low': nan,
#  'Residential segregation - non-white/white CI high': nan,
#  'Homicides raw value': 0.7,
#  'Homicides numerator': 10.0,
#  'Homicides denominator': 38744.0,
#  'Homicides CI low': 0.4,
#  'Homicides CI high': 1.1,
#  'Firearm fatalities raw value': 1.7,
#  'Firearm fatalities numerator': 10.0,
#  'Firearm fatalities denominator': 19579.0,
#  'Firearm fatalities CI low': 1.2,
#  'Firearm fatalities CI high': 2.0,
#  'Homeownership raw value': 0.037735849,
#  'Homeownership numerator': 2,
#  'Homeownership denominator': 31,
#  'Homeownership CI low': 0.0,
#  'Homeownership CI high': 0.082182557,
#  'Severe housing cost burden raw value': 0.00462963,
#  'Severe housing cost burden numerator': 1.0,
#  'Severe housing cost burden denominator': 30.0,
#  'Severe housing cost burden CI low': 0.0,
#  'Severe housing cost burden CI high': 0.05557466,
#  'Population raw value': 88,
#  'Population numerator': nan,
#  'Population denominator': nan,
#  'Population CI low': nan,
#  'Population CI high': nan,
#  '% below 18 years of age raw value': 0.0,
#  '% below 18 years of age numerator': nan,
#  '% below 18 years of age denominator': nan,
#  '% below 18 years of age CI low': nan,
#  '% below 18 years of age CI high': nan,
#  '% 65 and older raw value': 0.047665088,
#  '% 65 and older numerator': nan,
#  '% 65 and older denominator': nan,
#  '% 65 and older CI low': nan,
#  '% 65 and older CI high': nan,
#  '% Non-Hispanic African American raw value': 0.0,
#  '% Non-Hispanic African American numerator': 0,
#  '% Non-Hispanic African American denominator': 88,
#  '% Non-Hispanic African American CI low': nan,
#  '% Non-Hispanic African American CI high': nan,
#  '% American Indian and Alaskan Native raw value': 0.0,
#  '% American Indian and Alaskan Native numerator': 0,
#  '% American Indian and Alaskan Native denominator': 88,
#  '% American Indian and Alaskan Native CI low': nan,
#  '% American Indian and Alaskan Native CI high': nan,
#  '% Asian raw value': 0.0,
#  '% Asian numerator': 0,
#  '% Asian denominator': 88,
#  '% Asian CI low': nan,
#  '% Asian CI high': nan,
#  '% Native Hawaiian/Other Pacific Islander raw value': 0.0,
#  '% Native Hawaiian/Other Pacific Islander numerator': 0,
#  '% Native Hawaiian/Other Pacific Islander denominator': 88,
#  '% Native Hawaiian/Other Pacific Islander CI low': nan,
#  '% Native Hawaiian/Other Pacific Islander CI high': nan,
#  '% Hispanic raw value': 0.005151515,
#  '% Hispanic numerator': 1,
#  '% Hispanic denominator': 88,
#  '% Hispanic CI low': nan,
#  '% Hispanic CI high': nan,
#  '% Non-Hispanic white raw value': 0.027604095,
#  '% Non-Hispanic white numerator': 23,
#  '% Non-Hispanic white denominator': 88,
#  '% Non-Hispanic white CI low': nan,
#  '% Non-Hispanic white CI high': nan,
#  '% not proficient in English raw value': 0.0,
#  '% not proficient in English numerator': 0,
#  '% not proficient in English denominator': 74,
#  '% not proficient in English CI low': 0.0,
#  '% not proficient in English CI high': 0.002352453,
#  '% Females raw value': 0.265748709,
#  '% Females numerator': nan,
#  '% Females denominator': nan,
#  '% Females CI low': nan,
#  '% Females CI high': nan,
#  '% Rural raw value': 0.0,
#  '% Rural numerator': 0.0,
#  '% Rural denominator': 82.0,
#  '% Rural CI low': nan,
#  '% Rural CI high': nan,
#  'Communicable disease raw value': 425.3141525,
#  'Communicable disease numerator': 26.0,
#  'Communicable disease denominator': 4378.0,
#  'Communicable disease CI low': nan,
#  'Communicable disease CI high': nan,
#  'Self-inflicted injury hospitalizations raw value': 12.1,
#  'Self-inflicted injury hospitalizations numerator': 5.0,
#  'Self-inflicted injury hospitalizations denominator': nan,
#  'Self-inflicted injury hospitalizations CI low': 1.5,
#  'Self-inflicted injury hospitalizations CI high': 22.7,
#  'Cancer incidence raw value': 330.3,
#  'Cancer incidence numerator': 93.0,
#  'Cancer incidence denominator': 22119.0,
#  'Cancer incidence CI low': 305.5,
#  'Cancer incidence CI high': 356.5,
#  'Coronary heart disease hospitalizations raw value': 1.1,
#  'Coronary heart disease hospitalizations numerator': 22.0,
#  'Coronary heart disease hospitalizations denominator': nan,
#  'Coronary heart disease hospitalizations CI low': nan,
#  'Coronary heart disease hospitalizations CI high': nan,
#  'Cerebrovascular disease hospitalizations raw value': 1.3,
#  'Cerebrovascular disease hospitalizations numerator': 20.0,
#  'Cerebrovascular disease hospitalizations denominator': nan,
#  'Cerebrovascular disease hospitalizations CI low': nan,
#  'Cerebrovascular disease hospitalizations CI high': nan,
#  'Smoking during pregnancy raw value': 0.049876767,
#  'Smoking during pregnancy numerator': 18.0,
#  'Smoking during pregnancy denominator': 124.0,
#  'Smoking during pregnancy CI low': nan,
#  'Smoking during pregnancy CI high': nan,
#  'Drug arrests raw value': 4.0,
#  'Drug arrests numerator': nan,
#  'Drug arrests denominator': nan,
#  'Drug arrests CI low': nan,
#  'Drug arrests CI high': nan,
#  'Opioid hospital visits raw value': 96.3,
#  'Opioid hospital visits numerator': 12.0,
#  'Opioid hospital visits denominator': 4346.0,
#  'Opioid hospital visits CI low': 66.0,
#  'Opioid hospital visits CI high': 123.3,
#  'Alcohol-related hospitalizations raw value': 0.5,
#  'Alcohol-related hospitalizations numerator': 20.0,
#  'Alcohol-related hospitalizations denominator': nan,
#  'Alcohol-related hospitalizations CI low': nan,
#  'Alcohol-related hospitalizations CI high': nan,
#  'Motor vehicle crash occupancy rate raw value': 15.95508938,
#  'Motor vehicle crash occupancy rate numerator': 216.0,
#  'Motor vehicle crash occupancy rate denominator': 13025.0,
#  'Motor vehicle crash occupancy rate CI low': nan,
#  'Motor vehicle crash occupancy rate CI high': nan,
#  'On-road motor vehicle crash-related ER visits raw value': 67.2,
#  'On-road motor vehicle crash-related ER visits numerator': 6.0,
#  'On-road motor vehicle crash-related ER visits denominator': nan,
#  'On-road motor vehicle crash-related ER visits CI low': 13.5,
#  'On-road motor vehicle crash-related ER visits CI high': 121.0,
#  'Off-road motor vehicle crash-related ER visits raw value': 32.3,
#  'Off-road motor vehicle crash-related ER visits numerator': 5.0,
#  'Off-road motor vehicle crash-related ER visits denominator': nan,
#  'Off-road motor vehicle crash-related ER visits CI low': 5.3,
#  'Off-road motor vehicle crash-related ER visits CI high': 35.7,
#  'Childhood immunizations raw value': 0.4266,
#  'Childhood immunizations numerator': nan,
#  'Childhood immunizations denominator': nan,
#  'Childhood immunizations CI low': nan,
#  'Childhood immunizations CI high': nan,
#  'Reading proficiency raw value': 0.11111,
#  'Reading proficiency numerator': 7.0,
#  'Reading proficiency denominator': 22.0,
#  'Reading proficiency CI low': nan,
#  'Reading proficiency CI high': nan,
#  'W-2 enrollment raw value': 1.0,
#  'W-2 enrollment numerator': nan,
#  'W-2 enrollment denominator': nan,
#  'W-2 enrollment CI low': nan,
#  'W-2 enrollment CI high': nan,
#  'Poverty raw value': 0.045,
#  'Poverty numerator': 520.0,
#  'Poverty denominator': nan,
#  'Poverty CI low': 0.033085106,
#  'Poverty CI high': 0.055127273,
#  'Older adults living alone raw value': 0.231687167,
#  'Older adults living alone numerator': 138.0,
#  'Older adults living alone denominator': 565.0,
#  'Older adults living alone CI low': nan,
#  'Older adults living alone CI high': nan,
#  'Hate crimes raw value': 0.384023103,
#  'Hate crimes numerator': 1.0,
#  'Hate crimes denominator': 4456.0,
#  'Hate crimes CI low': nan,
#  'Hate crimes CI high': nan,
#  'Child abuse raw value': 0.0,
#  'Child abuse numerator': 0.0,
#  'Child abuse denominator': 655.0,
#  'Child abuse CI low': nan,
#  'Child abuse CI high': nan,
#  'Injury hospitalizations raw value': 119.9,
#  'Injury hospitalizations numerator': 5.0,
#  'Injury hospitalizations denominator': nan,
#  'Injury hospitalizations CI low': 18.4,
#  'Injury hospitalizations CI high': 210.5,
#  'Fall fatalities 65+ raw value': 42.5,
#  'Fall fatalities 65+ numerator': 5.0,
#  'Fall fatalities 65+ denominator': 1727.0,
#  'Fall fatalities 65+ CI low': 5.3,
#  'Fall fatalities 65+ CI high': 73.4,
#  'Year structure built raw value': 0.07894139,
#  'Year structure built numerator': 189.0,
#  'Year structure built denominator': 2332.0,
#  'Year structure built CI low': nan,
#  'Year structure built CI high': nan,
#  'Male population 0-17 raw value': 359.0,
#  'Male population 18-44 raw value': 509.0,
#  'Male population 45-64 raw value': 560.0,
#  'Male population 65+ raw value': 267.0,
#  'Total male population raw value': 2176.0,
#  'Female population 0-17 raw value': 324.0,
#  'Female population 18-44 raw value': 483.0,
#  'Female population 45-64 raw value': 581.0,
#  'Female population 65+ raw value': 341.0,
#  'Total female population raw value': 2157.0,
#  'Population growth raw value': -0.02172433}

# %%
dict(health_ranking.max())
# Out:
# {'State FIPS Code': 56,
#  'County FIPS Code': 840,
#  '5-digit FIPS Code': 56045,
#  'State Abbreviation': 'WY',
#  'Name': 'Ziebach County',
#  'Release Year': 2019,
#  'County Ranked (Yes=1/No=0)': 1.0,
#  'Premature death raw value': 35146.6452,
#  'Premature death numerator': 343591.0,
#  'Premature death denominator': 111152946.0,
#  'Premature death CI low': 26393.98032,
#  'Premature death CI high': 49887.85737,
#  'Premature death (Black)': 28271.76127,
#  'Premature death (Hispanic)': 16351.18936,
#  'Premature death (White)': 24451.87754,
#  'Poor or fair health raw value': 0.407323552,
#  'Poor or fair health numerator': nan,
#  'Poor or fair health denominator': nan,
#  'Poor or fair health CI low': 0.392121857,
#  'Poor or fair health CI high': 0.42074221,
#  'Poor physical health days raw value': 7.230990498,
#  'Poor physical health days numerator': nan,
#  'Poor physical health days denominator': nan,
#  'Poor physical health days CI low': 6.903898184,
#  'Poor physical health days CI high': 7.567626322,
#  'Poor mental health days raw value': 5.964156153,
#  'Poor mental health days numerator': nan,
#  'Poor mental health days denominator': nan,
#  'Poor mental health days CI low': 5.710173282,
#  'Poor mental health days CI high': 6.240258788,
#  'Low birthweight raw value': 0.261363636,
#  'Low birthweight numerator': 234533.0,
#  'Low birthweight denominator': 3454882.0,
#  'Low birthweight CI low': 0.169561527,
#  'Low birthweight CI high': 0.353165746,
#  'Low birthweight (Black)': 0.333333333,
#  'Low birthweight (Hispanic)': 0.209677419,
#  'Low birthweight (White)': 0.208333333,
#  'Adult smoking raw value': 0.42754056,
#  'Adult smoking numerator': nan,
#  'Adult smoking denominator': nan,
#  'Adult smoking CI low': 0.412157783,
#  'Adult smoking CI high': 0.444594617,
#  'Adult obesity raw value': 0.495,
#  'Adult obesity numerator': 6555217,
#  'Adult obesity denominator': 28847093.86,
#  'Adult obesity CI low': 0.408,
#  'Adult obesity CI high': 0.578,
#  'Food environment index raw value': 10.0,
#  'Food environment index numerator': 0.718442093,
#  'Food environment index denominator': 0.361,
#  'Food environment index CI low': nan,
#  'Food environment index CI high': nan,
#  'Physical inactivity raw value': 0.451,
#  'Physical inactivity numerator': 5015516,
#  'Physical inactivity denominator': 28834773.12,
#  'Physical inactivity CI low': 0.409,
#  'Physical inactivity CI high': 0.496,
#  'Access to exercise opportunities raw value': 1.0,
#  'Access to exercise opportunities numerator': 34626653.0,
#  'Access to exercise opportunities denominator': 37253956.0,
#  'Access to exercise opportunities CI low': nan,
#  'Access to exercise opportunities CI high': nan,
#  'Excessive drinking raw value': 0.294401188,
#  'Excessive drinking numerator': nan,
#  'Excessive drinking denominator': nan,
#  'Excessive drinking CI low': 0.285328654,
#  'Excessive drinking CI high': 0.303082211,
#  'Alcohol-impaired driving deaths raw value': 1.0,
#  'Alcohol-impaired driving deaths numerator': 5069.0,
#  'Alcohol-impaired driving deaths denominator': 18026.0,
#  'Alcohol-impaired driving deaths CI low': 0.784582987,
#  'Alcohol-impaired driving deaths CI high': 0.893476419,
#  'Sexually transmitted infections raw value': 3543.9,
#  'Sexually transmitted infections numerator': 198155.0,
#  'Sexually transmitted infections denominator': 39144818.0,
#  'Sexually transmitted infections CI low': nan,
#  'Sexually transmitted infections CI high': nan,
#  'Teen births raw value': 110.2362205,
#  'Teen births numerator': 245210.0,
#  'Teen births denominator': 9009168.0,
#  'Teen births CI low': 98.2,
#  'Teen births CI high': 122.3,
#  'Teen births (Black)': 129.8701299,
#  'Teen births (Hispanic)': 255.8139535,
#  'Teen births (White)': 126.9565217,
#  'Uninsured raw value': 0.334537098,
#  'Uninsured numerator': 4444791.0,
#  'Uninsured denominator': 33261678.0,
#  'Uninsured CI low': 0.295217949,
#  'Uninsured CI high': 0.373856247,
#  'Primary care physicians raw value': 0.004772234,
#  'Primary care physicians numerator': 30801.0,
#  'Primary care physicians denominator': 39250017.0,
#  'Primary care physicians CI low': nan,
#  'Primary care physicians CI high': nan,
#  'Ratio of population to primary care physicians.': 46588.0,
#  'Dentists raw value': 0.007251281,
#  'Dentists numerator': 32957,
#  'Dentists denominator': 39536653,
#  'Dentists CI low': nan,
#  'Dentists CI high': nan,
#  'Ratio of population to dentists.': 29302.0,
#  'Mental health providers raw value': 0.020026555,
#  'Mental health providers numerator': 129604,
#  'Mental health providers denominator': 39536653,
#  'Mental health providers CI low': nan,
#  'Mental health providers CI high': nan,
#  'Ratio of population to mental health providers.': 24079.0,
#  'Preventable hospital stays raw value': 33333.0,
#  'Preventable hospital stays numerator': nan,
#  'Preventable hospital stays denominator': nan,
#  'Preventable hospital stays CI low': nan,
#  'Preventable hospital stays CI high': nan,
#  'Preventable hospital stays (Black)': 46154.0,
#  'Preventable hospital stays (Hispanic)': 33333.0,
#  'Preventable hospital stays (White)': 16510.0,
#  'Mammography screening raw value': 0.62,
#  'Mammography screening numerator': nan,
#  'Mammography screening denominator': nan,
#  'Mammography screening CI low': nan,
#  'Mammography screening CI high': nan,
#  'Mammography screening (Black)': 0.75,
#  'Mammography screening (Hispanic)': 0.79,
#  'Mammography screening (White)': 0.63,
#  'Flu vaccinations raw value': 0.65,
#  'Flu vaccinations numerator': nan,
#  'Flu vaccinations denominator': nan,
#  'Flu vaccinations CI low': nan,
#  'Flu vaccinations CI high': nan,
#  'Flu vaccinations (Black)': 0.69,
#  'Flu vaccinations (Hispanic)': 0.73,
#  'Flu vaccinations (White)': 0.65,
#  'High school graduation raw value': 1.0,
#  'High school graduation numerator': 371993.78,
#  'High school graduation denominator': 429276.0,
#  'High school graduation CI low': nan,
#  'High school graduation CI high': nan,
#  'Some college raw value': 0.936708861,
#  'Some college numerator': 7066241,
#  'Some college denominator': 11002942,
#  'Some college CI low': 0.880686032,
#  'Some college CI high': 1.0,
#  'Unemployment raw value': 0.200713013,
#  'Unemployment numerator': 918883.0,
#  'Unemployment denominator': 19311960.0,
#  'Unemployment CI low': nan,
#  'Unemployment CI high': nan,
#  'Children in poverty raw value': 0.747,
#  'Children in poverty numerator': 1615913.0,
#  'Children in poverty denominator': nan,
#  'Children in poverty CI low': 0.564702128,
#  'Children in poverty CI high': 0.929297872,
#  'Children in poverty (Black)': 0.978723404,
#  'Children in poverty (Hispanic)': 0.978947368,
#  'Children in poverty (White)': 0.812903226,
#  'Income inequality raw value': 10.09995947,
#  'Income inequality numerator': 231519,
#  'Income inequality denominator': 62609,
#  'Income inequality CI low': 8.879271717,
#  'Income inequality CI high': 16.72794138,
#  'Children in single-parent households raw value': 1.0,
#  'Children in single-parent households numerator': 2841431.0,
#  'Children in single-parent households denominator': 9036592.0,
#  'Children in single-parent households CI low': 0.709334576,
#  'Children in single-parent households CI high': 1.0,
#  'Social associations raw value': 70.62146893,
#  'Social associations numerator': 22866,
#  'Social associations denominator': 39250017,
#  'Social associations CI low': nan,
#  'Social associations CI high': nan,
#  'Violent crime raw value': 1819.514407,
#  'Violent crime numerator': 164252.5,
#  'Violent crime denominator': 39026258.5,
#  'Violent crime CI low': nan,
#  'Violent crime CI high': nan,
#  'Injury deaths raw value': 284.9567609,
#  'Injury deaths numerator': 95450.0,
#  'Injury deaths denominator': 195066509.0,
#  'Injury deaths CI low': 232.9,
#  'Injury deaths CI high': 486.0,
#  'Air pollution - particulate matter raw value': 19.7,
#  'Air pollution - particulate matter numerator': nan,
#  'Air pollution - particulate matter denominator': nan,
#  'Air pollution - particulate matter CI low': nan,
#  'Air pollution - particulate matter CI high': nan,
#  'Drinking water violations raw value': 1.0,
#  'Drinking water violations numerator': nan,
#  'Drinking water violations denominator': nan,
#  'Drinking water violations CI low': nan,
#  'Drinking water violations CI high': nan,
#  'Severe housing problems raw value': 0.712166172,
#  'Severe housing problems numerator': 3476695,
#  'Severe housing problems denominator': 12717800,
#  'Severe housing problems CI low': 0.682194256,
#  'Severe housing problems CI high': 0.742138089,
#  'Percentage of households with high housing costs': 0.313641721,
#  'Percentage of households with overcrowding': 0.519287834,
#  'Percentage of households with lack of kitchen or plumbing facilities': 0.376262626,
#  'Driving alone to work raw value': 0.972067039,
#  'Driving alone to work numerator': 12950487,
#  'Driving alone to work denominator': 17589758,
#  'Driving alone to work CI low': 0.924792444,
#  'Driving alone to work CI high': 1.0,
#  'Driving alone to work (Black)': 0.957055215,
#  'Driving alone to work (Hispanic)': 0.933447099,
#  'Driving alone to work (White)': 0.970238095,
#  'Long commute - driving alone raw value': 0.845,
#  'Long commute - driving alone numerator': nan,
#  'Long commute - driving alone denominator': 12950487,
#  'Long commute - driving alone CI low': 0.645738729,
#  'Long commute - driving alone CI high': 1.0,
#  'Life expectancy raw value': 97.96523541,
#  'Life expectancy numerator': nan,
#  'Life expectancy denominator': nan,
#  'Life expectancy CI low': 88.97656265,
#  'Life expectancy CI high': 110.9041596,
#  'Life expectancy (Black)': 93.61272259,
#  'Life expectancy (Hispanic)': 116.0053308,
#  'Life expectancy (White)': 94.07401434,
#  'Premature age-adjusted mortality raw value': 1146.1,
#  'Premature age-adjusted mortality numerator': 343591.0,
#  'Premature age-adjusted mortality denominator': 111152946.0,
#  'Premature age-adjusted mortality CI low': 1022.9,
#  'Premature age-adjusted mortality CI high': 1502.9,
#  'Premature age-adjusted mortality (Black)': 49004.52759,
#  'Premature age-adjusted mortality (Hispanic)': 867.3212154,
#  'Premature age-adjusted mortality (White)': 1196.621651,
#  'Child mortality raw value': 294.5841831,
#  'Child mortality numerator': 14857.0,
#  'Child mortality denominator': 36427067.0,
#  'Child mortality CI low': 163.0,
#  'Child mortality CI high': 503.7,
#  'Child mortality (Black)': 314.6303094,
#  'Child mortality (Hispanic)': 121.1435955,
#  'Child mortality (White)': 186.6832607,
#  'Infant mortality raw value': 31.11739745,
#  'Infant mortality numerator': 15805.0,
#  'Infant mortality denominator': 3509196.0,
#  'Infant mortality CI low': 19.5,
#  'Infant mortality CI high': 47.1,
#  'Infant mortality (Black)': 24.98163115,
#  'Infant mortality (Hispanic)': 10.56168987,
#  'Infant mortality (White)': 11.04190261,
#  'Frequent physical distress raw value': 0.246184544,
#  'Frequent physical distress numerator': nan,
#  'Frequent physical distress denominator': nan,
#  'Frequent physical distress CI low': 0.238009903,
#  'Frequent physical distress CI high': 0.254533201,
#  'Frequent mental distress raw value': 0.222063302,
#  'Frequent mental distress numerator': nan,
#  'Frequent mental distress denominator': nan,
#  'Frequent mental distress CI low': 0.214997265,
#  'Frequent mental distress CI high': 0.229263849,
#  'Diabetes prevalence raw value': 0.209,
#  'Diabetes prevalence numerator': 2454020,
#  'Diabetes prevalence denominator': 28875175.82,
#  'Diabetes prevalence CI low': 0.186,
#  'Diabetes prevalence CI high': 0.256,
#  'HIV prevalence raw value': 2590.2,
#  'HIV prevalence numerator': 128681.0,
#  'HIV prevalence denominator': 32433206.0,
#  'HIV prevalence CI low': nan,
#  'HIV prevalence CI high': nan,
#  'Food insecurity raw value': 0.361,
#  'Food insecurity numerator': 4574710,
#  'Food insecurity denominator': nan,
#  'Food insecurity CI low': nan,
#  'Food insecurity CI high': nan,
#  'Limited access to healthy foods raw value': 0.718442093,
#  'Limited access to healthy foods numerator': 2180417.408,
#  'Limited access to healthy foods denominator': 37253956,
#  'Limited access to healthy foods CI low': nan,
#  'Limited access to healthy foods CI high': nan,
#  'Drug overdose deaths raw value': 111.5400519,
#  'Drug overdose deaths numerator': 14181.0,
#  'Drug overdose deaths denominator': 117931488.0,
#  'Drug overdose deaths CI low': 99.3,
#  'Drug overdose deaths CI high': 128.0,
#  'Motor vehicle crash deaths raw value': 92.16185377,
#  'Motor vehicle crash deaths numerator': 24971.0,
#  'Motor vehicle crash deaths denominator': 270799851.0,
#  'Motor vehicle crash deaths CI low': 60.7,
#  'Motor vehicle crash deaths CI high': 151.0,
#  'Insufficient sleep raw value': 0.467077835,
#  'Insufficient sleep numerator': nan,
#  'Insufficient sleep denominator': nan,
#  'Insufficient sleep CI low': 0.456602086,
#  'Insufficient sleep CI high': 0.478273909,
#  'Uninsured adults raw value': 0.406791809,
#  'Uninsured adults numerator': 3783923.0,
#  'Uninsured adults denominator': 24285936.0,
#  'Uninsured adults CI low': 0.387727979,
#  'Uninsured adults CI high': 0.433303436,
#  'Uninsured children raw value': 0.232258065,
#  'Uninsured children numerator': 735079.0,
#  'Uninsured children denominator': 9452917.0,
#  'Uninsured children CI low': 0.170997941,
#  'Uninsured children CI high': 0.294215511,
#  'Other primary care providers raw value': 0.014338879,
#  'Other primary care providers numerator': 22338,
#  'Other primary care providers denominator': 39536653,
#  'Other primary care providers CI low': nan,
#  'Other primary care providers CI high': nan,
#  'Ratio of population to primary care providers other than physicians.': 51307.0,
#  'Disconnected youth raw value': 0.638554217,
#  'Disconnected youth numerator': 146868.0,
#  'Disconnected youth denominator': 2099516.0,
#  'Disconnected youth CI low': 0.330353891,
#  'Disconnected youth CI high': 0.946754543,
#  'Median household income raw value': 136191.0,
#  'Median household income numerator': nan,
#  'Median household income denominator': nan,
#  'Median household income CI low': 132074.4043,
#  'Median household income CI high': 140307.5957,
#  'Median household income (Black)': 248604.0,
#  'Median household income (Hispanic)': 180804.0,
#  'Median household income (White)': 142670.0,
#  'Children eligible for free or reduced price lunch raw value': 1.0,
#  'Children eligible for free or reduced price lunch numerator': 3611454.0,
#  'Children eligible for free or reduced price lunch denominator': 6214474.0,
#  'Children eligible for free or reduced price lunch CI low': nan,
#  'Children eligible for free or reduced price lunch CI high': nan,
#  'Residential segregation - Black/White raw value': 91.12375269,
#  'Residential segregation - Black/White numerator': nan,
#  'Residential segregation - Black/White denominator': nan,
#  'Residential segregation - Black/White CI low': nan,
#  'Residential segregation - Black/White CI high': nan,
#  'Residential segregation - non-white/white raw value': 91.09908509,
#  'Residential segregation - non-white/white numerator': nan,
#  'Residential segregation - non-white/white denominator': nan,
#  'Residential segregation - non-white/white CI low': nan,
#  'Residential segregation - non-white/white CI high': nan,
#  'Homicides raw value': 39.5,
#  'Homicides numerator': 13428.0,
#  'Homicides denominator': 270799851.0,
#  'Homicides CI low': 37.1,
#  'Homicides CI high': 50.8,
#  'Firearm fatalities raw value': 76.8,
#  'Firearm fatalities numerator': 15695.0,
#  'Firearm fatalities denominator': 195066509.0,
#  'Firearm fatalities CI low': 52.2,
#  'Firearm fatalities CI high': 109.0,
#  'Homeownership raw value': 0.93452381,
#  'Homeownership numerator': 7024315,
#  'Homeownership denominator': 12888128,
#  'Homeownership CI low': 0.891696253,
#  'Homeownership CI high': 1.0,
#  'Severe housing cost burden raw value': 0.316406882,
#  'Severe housing cost burden numerator': 2573539.0,
#  'Severe housing cost burden denominator': 12532338.0,
#  'Severe housing cost burden CI low': 0.310234574,
#  'Severe housing cost burden CI high': 1.0,
#  'Population raw value': 39536653,
#  'Population numerator': nan,
#  'Population denominator': nan,
#  'Population CI low': nan,
#  'Population CI high': nan,
#  '% below 18 years of age raw value': 0.412419275,
#  '% below 18 years of age numerator': nan,
#  '% below 18 years of age denominator': nan,
#  '% below 18 years of age CI low': nan,
#  '% below 18 years of age CI high': nan,
#  '% 65 and older raw value': 0.569440339,
#  '% 65 and older numerator': nan,
#  '% 65 and older denominator': nan,
#  '% 65 and older CI low': nan,
#  '% 65 and older CI high': nan,
#  '% Non-Hispanic African American raw value': 0.853296089,
#  '% Non-Hispanic African American numerator': 3368473,
#  '% Non-Hispanic African American denominator': 39536653,
#  '% Non-Hispanic African American CI low': nan,
#  '% Non-Hispanic African American CI high': nan,
#  '% American Indian and Alaskan Native raw value': 0.926969032,
#  '% American Indian and Alaskan Native numerator': 650250,
#  '% American Indian and Alaskan Native denominator': 39536653,
#  '% American Indian and Alaskan Native CI low': nan,
#  '% American Indian and Alaskan Native CI high': nan,
#  '% Asian raw value': 0.430067263,
#  '% Asian numerator': 5993089,
#  '% Asian denominator': 39536653,
#  '% Asian CI low': nan,
#  '% Asian CI high': nan,
#  '% Native Hawaiian/Other Pacific Islander raw value': 0.477272727,
#  '% Native Hawaiian/Other Pacific Islander numerator': 199449,
#  '% Native Hawaiian/Other Pacific Islander denominator': 39536653,
#  '% Native Hawaiian/Other Pacific Islander CI low': nan,
#  '% Native Hawaiian/Other Pacific Islander CI high': nan,
#  '% Hispanic raw value': 0.96322959,
#  '% Hispanic numerator': 15477304,
#  '% Hispanic denominator': 39536653,
#  '% Hispanic CI low': nan,
#  '% Hispanic CI high': nan,
#  '% Non-Hispanic white raw value': 0.979227161,
#  '% Non-Hispanic white numerator': 14696754,
#  '% Non-Hispanic white denominator': 39536653,
#  '% Non-Hispanic white CI low': nan,
#  '% Non-Hispanic white CI high': nan,
#  '% not proficient in English raw value': 0.353053435,
#  '% not proficient in English numerator': 3664918,
#  '% not proficient in English denominator': 36489302,
#  '% not proficient in English CI low': 0.250333936,
#  '% not proficient in English CI high': 0.853485743,
#  '% Females raw value': 0.570038389,
#  '% Females numerator': nan,
#  '% Females denominator': nan,
#  '% Females CI low': nan,
#  '% Females CI high': nan,
#  '% Rural raw value': 1.0,
#  '% Rural numerator': 3847522.0,
#  '% Rural denominator': 37253956.0,
#  '% Rural CI low': nan,
#  '% Rural CI high': nan,
#  'Communicable disease raw value': 2053.394134,
#  'Communicable disease numerator': 59683.0,
#  'Communicable disease denominator': 5778829.0,
#  'Communicable disease CI low': nan,
#  'Communicable disease CI high': nan,
#  'Self-inflicted injury hospitalizations raw value': 115.0,
#  'Self-inflicted injury hospitalizations numerator': 5689.0,
#  'Self-inflicted injury hospitalizations denominator': nan,
#  'Self-inflicted injury hospitalizations CI low': 71.8,
#  'Self-inflicted injury hospitalizations CI high': 186.3,
#  'Cancer incidence raw value': 584.3,
#  'Cancer incidence numerator': 158866.0,
#  'Cancer incidence denominator': 28704939.0,
#  'Cancer incidence CI low': 547.8,
#  'Cancer incidence CI high': 623.1,
#  'Coronary heart disease hospitalizations raw value': 7.5,
#  'Coronary heart disease hospitalizations numerator': 16243.0,
#  'Coronary heart disease hospitalizations denominator': nan,
#  'Coronary heart disease hospitalizations CI low': nan,
#  'Coronary heart disease hospitalizations CI high': nan,
#  'Cerebrovascular disease hospitalizations raw value': 4.6,
#  'Cerebrovascular disease hospitalizations numerator': 14684.0,
#  'Cerebrovascular disease hospitalizations denominator': nan,
#  'Cerebrovascular disease hospitalizations CI low': nan,
#  'Cerebrovascular disease hospitalizations CI high': nan,
#  'Smoking during pregnancy raw value': 0.352534562,
#  'Smoking during pregnancy numerator': 31579.0,
#  'Smoking during pregnancy denominator': 264334.0,
#  'Smoking during pregnancy CI low': nan,
#  'Smoking during pregnancy CI high': nan,
#  'Drug arrests raw value': 29106.0,
#  'Drug arrests numerator': nan,
#  'Drug arrests denominator': nan,
#  'Drug arrests CI low': nan,
#  'Drug arrests CI high': nan,
#  'Opioid hospital visits raw value': 1214.8,
#  'Opioid hospital visits numerator': 27101.0,
#  'Opioid hospital visits denominator': 5774977.0,
#  'Opioid hospital visits CI low': 1044.4,
#  'Opioid hospital visits CI high': 1493.7,
#  'Alcohol-related hospitalizations raw value': 6.2,
#  'Alcohol-related hospitalizations numerator': 11911.0,
#  'Alcohol-related hospitalizations denominator': nan,
#  'Alcohol-related hospitalizations CI low': nan,
#  'Alcohol-related hospitalizations CI high': nan,
#  'Motor vehicle crash occupancy rate raw value': 73.07491798,
#  'Motor vehicle crash occupancy rate numerator': 915643.0,
#  'Motor vehicle crash occupancy rate denominator': 17283933.0,
#  'Motor vehicle crash occupancy rate CI low': nan,
#  'Motor vehicle crash occupancy rate CI high': nan,
#  'On-road motor vehicle crash-related ER visits raw value': 1487.9,
#  'On-road motor vehicle crash-related ER visits numerator': 80434.0,
#  'On-road motor vehicle crash-related ER visits denominator': nan,
#  'On-road motor vehicle crash-related ER visits CI low': 1470.7,
#  'On-road motor vehicle crash-related ER visits CI high': 1563.3,
#  'Off-road motor vehicle crash-related ER visits raw value': 506.2,
#  'Off-road motor vehicle crash-related ER visits numerator': 8958.0,
#  'Off-road motor vehicle crash-related ER visits denominator': nan,
#  'Off-road motor vehicle crash-related ER visits CI low': 357.0,
#  'Off-road motor vehicle crash-related ER visits CI high': 655.4,
#  'Childhood immunizations raw value': 0.8232,
#  'Childhood immunizations numerator': nan,
#  'Childhood immunizations denominator': nan,
#  'Childhood immunizations CI low': nan,
#  'Childhood immunizations CI high': nan,
#  'Reading proficiency raw value': 0.73291,
#  'Reading proficiency numerator': 29302.0,
#  'Reading proficiency denominator': 61373.0,
#  'Reading proficiency CI low': nan,
#  'Reading proficiency CI high': nan,
#  'W-2 enrollment raw value': 8331.0,
#  'W-2 enrollment numerator': nan,
#  'W-2 enrollment denominator': nan,
#  'W-2 enrollment CI low': nan,
#  'W-2 enrollment CI high': nan,
#  'Poverty raw value': 0.276,
#  'Poverty numerator': 640174.0,
#  'Poverty denominator': nan,
#  'Poverty CI low': 0.205702128,
#  'Poverty CI high': 0.346084849,
#  'Older adults living alone raw value': 0.345087302,
#  'Older adults living alone numerator': 259331.0,
#  'Older adults living alone denominator': 896724.0,
#  'Older adults living alone CI low': nan,
#  'Older adults living alone CI high': nan,
#  'Hate crimes raw value': 7.078643732,
#  'Hate crimes numerator': 39.0,
#  'Hate crimes denominator': 5778708.0,
#  'Hate crimes CI low': nan,
#  'Hate crimes CI high': nan,
#  'Child abuse raw value': 22.90076336,
#  'Child abuse numerator': 5061.0,
#  'Child abuse denominator': 1282644.0,
#  'Child abuse CI low': nan,
#  'Child abuse CI high': nan,
#  'Injury hospitalizations raw value': 857.5,
#  'Injury hospitalizations numerator': 29647.0,
#  'Injury hospitalizations denominator': nan,
#  'Injury hospitalizations CI low': 603.0,
#  'Injury hospitalizations CI high': 1131.6,
#  'Fall fatalities 65+ raw value': 213.4,
#  'Fall fatalities 65+ numerator': 3665.0,
#  'Fall fatalities 65+ denominator': 2703638.0,
#  'Fall fatalities 65+ CI low': 178.0,
#  'Fall fatalities 65+ CI high': 291.3,
#  'Year structure built raw value': 0.404528089,
#  'Year structure built numerator': 674504.0,
#  'Year structure built denominator': 2668692.0,
#  'Year structure built CI low': nan,
#  'Year structure built CI high': nan,
#  'Male population 0-17 raw value': 656000.0,
#  'Male population 18-44 raw value': 1004204.0,
#  'Male population 45-64 raw value': 781937.0,
#  'Male population 65+ raw value': 432330.0,
#  'Total male population raw value': 2874471.0,
#  'Female population 0-17 raw value': 626656.0,
#  'Female population 18-44 raw value': 969103.0,
#  'Female population 45-64 raw value': 789101.0,
#  'Female population 65+ raw value': 519498.0,
#  'Total female population raw value': 2904358.0,
#  'Population growth raw value': 0.069831767}

# %% [markdown]
# #### Missing values:
# * The health ranking dataset has many missing values and this can have a significant effect on the conclusions that can be drawn from the data.
# #### Inconsistent values:
# * There exists a few columns with  inconsistent data. Eg: 'Population growth raw value', Ratio of population to primary care providers other than physicians have negative values.

# %% [markdown]
# ##### The lost data can cause bias in the estimation of parameters like mean(), median() etc. which in-turn may complicate the analysis of the study. Each of these distortions may threaten the validity of the trials and can lead to invalid conclusions.

# %%
opioid_rate.isnull().sum()
# Out:
# State                    0
# County                   0
# FIPS                     0
# Opiod_Dispensing_Rate    0
# dtype: int64

# %%
opioid_rate.min(),opioid_rate.max()
# Out:
# (State                                  AK
#  County                   Abbeville County
#  FIPS                                 1001
#  Opiod_Dispensing_Rate                 0.0
#  dtype: object,
#  State                               WY
#  County                   Zavala County
#  FIPS                             56045
#  Opiod_Dispensing_Rate            567.9
#  dtype: object)

# %% [markdown]
# #### There are no missing values in opioid_rate dataframe. From the min() and max() values we can see that there are no inconsistent values.

# %% [markdown]
# ### Describe solutions to fix it.
# * If whole column is empty or NULL, we can discard/remove/drop it.
# * If there are few missing values in a column, then it can replaced by the mean, rolling average values. It will benefit by not distorting different parameters for analysis.
# * We can use fillna() to fill it with any relevant values for the column.
